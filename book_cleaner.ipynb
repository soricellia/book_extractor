# %%
import os
import re

# Define patterns to identify chapter names
chapter_patterns = [
    r"^Chapter \d+",         # e.g., "Chapter 1"
    r"^Chapter [A-Za-z]+",   # e.g., "Chapter One"
    r"^Part \d+",            # e.g., "Part 1"
    r"^Section \d+",         # e.g., "Section 1"
    r"^\d+\.\d+",            # e.g., "1.1"
    r"^\d+$",                # e.g., "1" (sometimes used for chapter names)
]

# Function to detect chapter titles based on patterns
def is_chapter_title(text):
    for pattern in chapter_patterns:
        if re.match(pattern, text.strip()):
            return True
    return False

# Function to extract chapters from a cleaned book text file
def extract_chapters_from_cleaned_text(cleaned_text_path):
    """
    Extract chapters from the cleaned book text and save each chapter into a separate text file.

    Args:
    - cleaned_text_path (str): Path to the cleaned book text file.

    Returns:
    - None
    """
    # Read the entire cleaned text
    with open(cleaned_text_path, "r", encoding="utf-8") as file:
        book_text = file.read()

    # Split the book text into lines for easier processing
    lines = book_text.splitlines()

    # Store the chapters as separate files in a directory
    book_name = os.path.splitext(os.path.basename(cleaned_text_path))[0]
    output_dir = f"./books/{book_name}_chapters"
    os.makedirs(output_dir, exist_ok=True)

    # Initialize variables for chapter extraction
    chapters = []          # List to hold chapter content
    current_chapter = []   # Accumulate lines for the current chapter
    current_title = None   # Track the current chapter title
    chapter_index = 0      # Chapter counter for filenames

    # Iterate over each line to detect chapter titles
    for line in lines:
        if is_chapter_title(line.strip()):
            # If a new chapter title is found, save the previous chapter if it exists
            if current_title and current_chapter:
                chapters.append((current_title, "\n".join(current_chapter)))

            # Start a new chapter
            current_title = line.strip()
            current_chapter = []  # Reset current chapter content
            chapter_index += 1
            print(f"New chapter detected: {current_title}")

        # Accumulate the line into the current chapter
        if current_chapter is not None:
            current_chapter.append(line)

    # Save the last chapter after iteration completes
    if current_title and current_chapter:
        chapters.append((current_title, "\n".join(current_chapter)))

    # Write each chapter to a separate file
    for index, (title, content) in enumerate(chapters, start=1):
        # Sanitize the chapter title to use as filename
        sanitized_title = re.sub(r'[\\/*?:"<>|]', "", title)  # Remove invalid filename chars
        sanitized_title = re.sub(r'\(.*?\)|\[.*?\]', "", sanitized_title).strip()  # Remove parenthetical
        sanitized_title = sanitized_title if sanitized_title else f"Chapter_{index}"
        chapter_filename = f"{output_dir}/{sanitized_title}_Chapter_{index}.txt"

        # Write the chapter to a file
        with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
            chapter_file.write(content)

        print(f"Chapter '{title}' written to {chapter_filename}")

# Example usage
cleaned_text_path = "./cleaned_books/Designing Data Intensive Applications_cleaned.txt"
extract_chapters_from_cleaned_text(cleaned_text_path)
# Out:
# New chapter detected: Chapter 11. Finally, in Chapter 12 we put everything together and discuss
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: Chapter 1: Reliable, Scalable, and Maintainable Applications
# New chapter detected: 10.1145/2408776.2408794
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: 10.1145/362384.362685
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: 10.1145/355611.362534
# New chapter detected: Chapter 2: Data Models and Query Languages
# New chapter detected: 10.1109/69.43410
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 7 and batch processing in Chapter 10.
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: 10.1145/130283.130338
# New chapter detected: 10.1145/2377677.2377681
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: 10.1145/1376616.1376713
# New chapter detected: 10.1145/2723372.2749441
# New chapter detected: 10.1561/1900000024
# New chapter detected: Chapter 3: Storage and Retrieval
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: Chapter 4: Encoding and Evolution
# New chapter detected: 10.1145/2525528.2525538
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 5: Replication
# New chapter detected: 1994.331722
# New chapter detected: 10.1145/800215.806583
# New chapter detected: Chapter 5: Replication
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 6: Partitioning
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: Chapter 7: Transactions
# New chapter detected: 10.1145/224056.224070
# New chapter detected: 10.1145/32204.32220
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: 42.003 seconds, even though x = 2 occurred unambiguously later. When node 2
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: 10.1145/2466486.2482856
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: 10.1145/2741948.2741976
# New chapter detected: 2010.5461931
# New chapter detected: 10.1145/52324.52356
# New chapter detected: 2003.1208949
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: 10.1145/1966989.1967009
# New chapter detected: 10.1145/2733108
# New chapter detected: 10.1145/2527748.2527767
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: 1504.02578, April 13, 2015.
# New chapter detected: 10.1145/347059.347561
# New chapter detected: 10.1016/0020-0190(85)90056-0
# New chapter detected: 10.1145/2523616.2523627
# New chapter detected: Chapter 8: The Trouble with Distributed Systems
# New chapter detected: Chapter 7: by using a transaction, the application can pretend that there are no
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: 10.1145/78969.78972
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: 1997.614100
# New chapter detected: 2011.389
# New chapter detected: 10.1109/MC.2012.37
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: 10.1145/7239.7266
# New chapter detected: 2004.02.022
# New chapter detected: 10.1145/62546.62549
# New chapter detected: Chapter 9: Consistency and Consensus
# New chapter detected: 10.1109/TDSC.2014.2355848
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: 216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"
# New chapter detected: 216.58.210.78. The user was not authenticated, so $remote_user is set to a hyphen
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 4).
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: 10.1145/1806596.1806638
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: 10.1145/2723372.2742790
# New chapter detected: 10.1145/79173.79181
# New chapter detected: 10.1145/2901919
# New chapter detected: Chapter 10: Batch Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: 10.1145/212433.220201
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: 10.1145/1661785.1667562
# New chapter detected: 2016.141
# New chapter detected: 10.1145/2463676.2465272
# New chapter detected: Chapter 11: Stream Processing
# New chapter detected: 10.1145/568522.568525
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: 10.1145/361011.361061
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: 10.1145/2501654.2501666
# New chapter detected: 10.1145/2723372.2737784
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: 10.1145/2678373.2665726
# New chapter detected: Chapter 12: The Future of Data Systems
# New chapter detected: 10.14763/2016.1.404
# New chapter detected: Chapter 12: The Future of Data Systems
# Chapter 'Chapter 11. Finally, in Chapter 12 we put everything together and discuss' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11. Finally, in Chapter 12 we put everything together and discuss_Chapter_1.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_2.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_3.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_4.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_5.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_6.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_7.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_8.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_9.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_10.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_11.txt
# Chapter 'Chapter 1: Reliable, Scalable, and Maintainable Applications' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 1 Reliable, Scalable, and Maintainable Applications_Chapter_12.txt
# Chapter '10.1145/2408776.2408794' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452408776.2408794_Chapter_13.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_14.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_15.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_16.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_17.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_18.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_19.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_20.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_21.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_22.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_23.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_24.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_25.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_26.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_27.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_28.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_29.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_30.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_31.txt
# Chapter '10.1145/362384.362685' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145362384.362685_Chapter_32.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_33.txt
# Chapter '10.1145/355611.362534' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145355611.362534_Chapter_34.txt
# Chapter 'Chapter 2: Data Models and Query Languages' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 2 Data Models and Query Languages_Chapter_35.txt
# Chapter '10.1109/69.43410' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.110969.43410_Chapter_36.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_37.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_38.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_39.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_40.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_41.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_42.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_43.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_44.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_45.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_46.txt
# Chapter 'Chapter 7 and batch processing in Chapter 10.' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 and batch processing in Chapter 10._Chapter_47.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_48.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_49.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_50.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_51.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_52.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_53.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_54.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_55.txt
# Chapter '10.1145/130283.130338' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145130283.130338_Chapter_56.txt
# Chapter '10.1145/2377677.2377681' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452377677.2377681_Chapter_57.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_58.txt
# Chapter '10.1145/1376616.1376713' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11451376616.1376713_Chapter_59.txt
# Chapter '10.1145/2723372.2749441' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452723372.2749441_Chapter_60.txt
# Chapter '10.1561/1900000024' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.15611900000024_Chapter_61.txt
# Chapter 'Chapter 3: Storage and Retrieval' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 3 Storage and Retrieval_Chapter_62.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_63.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_64.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_65.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_66.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_67.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_68.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_69.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_70.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_71.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_72.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_73.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_74.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_75.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_76.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_77.txt
# Chapter 'Chapter 4: Encoding and Evolution' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4 Encoding and Evolution_Chapter_78.txt
# Chapter '10.1145/2525528.2525538' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452525528.2525538_Chapter_79.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_80.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_81.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_82.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_83.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_84.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_85.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_86.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_87.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_88.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_89.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_90.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_91.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_92.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_93.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_94.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_95.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_96.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_97.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_98.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_99.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_100.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_101.txt
# Chapter '1994.331722' written to ./books/Designing Data Intensive Applications_cleaned_chapters/1994.331722_Chapter_102.txt
# Chapter '10.1145/800215.806583' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145800215.806583_Chapter_103.txt
# Chapter 'Chapter 5: Replication' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 5 Replication_Chapter_104.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_105.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_106.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_107.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_108.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_109.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_110.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_111.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_112.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_113.txt
# Chapter 'Chapter 6: Partitioning' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 6 Partitioning_Chapter_114.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_115.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_116.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_117.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_118.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_119.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_120.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_121.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_122.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_123.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_124.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_125.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_126.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_127.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_128.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_129.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_130.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_131.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_132.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_133.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_134.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_135.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_136.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_137.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_138.txt
# Chapter 'Chapter 7: Transactions' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 Transactions_Chapter_139.txt
# Chapter '10.1145/224056.224070' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145224056.224070_Chapter_140.txt
# Chapter '10.1145/32204.32220' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.114532204.32220_Chapter_141.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_142.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_143.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_144.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_145.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_146.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_147.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_148.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_149.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_150.txt
# Chapter '42.003 seconds, even though x = 2 occurred unambiguously later. When node 2' written to ./books/Designing Data Intensive Applications_cleaned_chapters/42.003 seconds, even though x = 2 occurred unambiguously later. When node 2_Chapter_151.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_152.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_153.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_154.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_155.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_156.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_157.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_158.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_159.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_160.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_161.txt
# Chapter '10.1145/2466486.2482856' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452466486.2482856_Chapter_162.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_163.txt
# Chapter '10.1145/2741948.2741976' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452741948.2741976_Chapter_164.txt
# Chapter '2010.5461931' written to ./books/Designing Data Intensive Applications_cleaned_chapters/2010.5461931_Chapter_165.txt
# Chapter '10.1145/52324.52356' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.114552324.52356_Chapter_166.txt
# Chapter '2003.1208949' written to ./books/Designing Data Intensive Applications_cleaned_chapters/2003.1208949_Chapter_167.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_168.txt
# Chapter '10.1145/1966989.1967009' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11451966989.1967009_Chapter_169.txt
# Chapter '10.1145/2733108' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452733108_Chapter_170.txt
# Chapter '10.1145/2527748.2527767' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452527748.2527767_Chapter_171.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_172.txt
# Chapter '1504.02578, April 13, 2015.' written to ./books/Designing Data Intensive Applications_cleaned_chapters/1504.02578, April 13, 2015._Chapter_173.txt
# Chapter '10.1145/347059.347561' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145347059.347561_Chapter_174.txt
# Chapter '10.1016/0020-0190(85)90056-0' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.10160020-019090056-0_Chapter_175.txt
# Chapter '10.1145/2523616.2523627' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452523616.2523627_Chapter_176.txt
# Chapter 'Chapter 8: The Trouble with Distributed Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 8 The Trouble with Distributed Systems_Chapter_177.txt
# Chapter 'Chapter 7: by using a transaction, the application can pretend that there are no' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 7 by using a transaction, the application can pretend that there are no_Chapter_178.txt
# Chapter 'Chapter 9: Consistency and Consensus' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 9 Consistency and Consensus_Chapter_179.txt
# Chapter 'Chapter 9: Consistency and Consensus' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 9 Consistency and Consensus_Chapter_180.txt
# Chapter 'Chapter 9: Consistency and Consensus' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 9 Consistency and Consensus_Chapter_181.txt
# Chapter 'Chapter 9: Consistency and Consensus' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 9 Consistency and Consensus_Chapter_182.txt
# Chapter 'Chapter 9: Consistency and Consensus' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 9 Consistency and Consensus_Chapter_183.txt
# ...
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_219.txt
# Chapter '216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"' written to ./books/Designing Data Intensive Applications_cleaned_chapters/216.58.210.78 - -  GET csstypography.css HTTP1.1_Chapter_220.txt
# Chapter '216.58.210.78. The user was not authenticated, so $remote_user is set to a hyphen' written to ./books/Designing Data Intensive Applications_cleaned_chapters/216.58.210.78. The user was not authenticated, so $remote_user is set to a hyphen_Chapter_221.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_222.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_223.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_224.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_225.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_226.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_227.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_228.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_229.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_230.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_231.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_232.txt
# Chapter 'Chapter 4).' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 4)._Chapter_233.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_234.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_235.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_236.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_237.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_238.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_239.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_240.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_241.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_242.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_243.txt
# Chapter '10.1145/1806596.1806638' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11451806596.1806638_Chapter_244.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_245.txt
# Chapter '10.1145/2723372.2742790' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452723372.2742790_Chapter_246.txt
# Chapter '10.1145/79173.79181' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.114579173.79181_Chapter_247.txt
# Chapter '10.1145/2901919' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452901919_Chapter_248.txt
# Chapter 'Chapter 10: Batch Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 10 Batch Processing_Chapter_249.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_250.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_251.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_252.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_253.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_254.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_255.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_256.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_257.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_258.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_259.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_260.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_261.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_262.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_263.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_264.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_265.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_266.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_267.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_268.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_269.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_270.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_271.txt
# Chapter '10.1145/212433.220201' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145212433.220201_Chapter_272.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_273.txt
# Chapter '10.1145/1661785.1667562' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11451661785.1667562_Chapter_274.txt
# Chapter '2016.141' written to ./books/Designing Data Intensive Applications_cleaned_chapters/2016.141_Chapter_275.txt
# Chapter '10.1145/2463676.2465272' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452463676.2465272_Chapter_276.txt
# Chapter 'Chapter 11: Stream Processing' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 11 Stream Processing_Chapter_277.txt
# Chapter '10.1145/568522.568525' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145568522.568525_Chapter_278.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_279.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_280.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_281.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_282.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_283.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_284.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_285.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_286.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_287.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_288.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_289.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_290.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_291.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_292.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_293.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_294.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_295.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_296.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_297.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_298.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_299.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_300.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_301.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_302.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_303.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_304.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_305.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_306.txt
# Chapter '10.1145/361011.361061' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.1145361011.361061_Chapter_307.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_308.txt
# Chapter '10.1145/2501654.2501666' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452501654.2501666_Chapter_309.txt
# Chapter '10.1145/2723372.2737784' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452723372.2737784_Chapter_310.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_311.txt
# Chapter '10.1145/2678373.2665726' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.11452678373.2665726_Chapter_312.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_313.txt
# Chapter '10.14763/2016.1.404' written to ./books/Designing Data Intensive Applications_cleaned_chapters/10.147632016.1.404_Chapter_314.txt
# Chapter 'Chapter 12: The Future of Data Systems' written to ./books/Designing Data Intensive Applications_cleaned_chapters/Chapter 12 The Future of Data Systems_Chapter_315.txt

# %%
import os
import re
import fitz  # PyMuPDF

# Define patterns for common page numbers and footers
page_number_patterns = [
    r'^\s*\d+\s*$',                   # Simple page number: 1, 2, 3, ...
    r'^\s*Page \d+\s*$',              # Page 1, Page 2, ...
    r'^\s*Page \d+ of \d+\s*$',       # Page 1 of 50
    r'^\s*\d+\s*/\s*\d+\s*$',         # 1/50, 2/50, ...
    r'^\s*-\s*\d+\s*-\s*$',           # - 1 -, - 2 -, ...
    r'^\s*\d+\s*\|\s*$',              # 1 | (common in OCR PDFs)
]

# Patterns for detecting likely footer content
footer_patterns = [
    r'^\d+\s*\|\s*Chapter.*$',         # e.g., "530 | Chapter 12: The Future"
    r'^\d+\s*\|\s*[A-Za-z].*$',        # e.g., "530 | Reliable, Scalable Systems"
    r'^\d+\s*-\s*.*$',                 # e.g., "530 - Chapter Summary"
]

# Function to detect and remove headers, footers, and page numbers
def detect_and_remove_headers_footers(text, page_num, total_pages):
    """
    Detect and clean up page numbers, headers, and footers in the given text.

    Args:
    - text (str): Text content of the page.
    - page_num (int): The current page number (0-based index).
    - total_pages (int): Total number of pages in the PDF.

    Returns:
    - cleaned_text (str): Text with headers, footers, and page numbers removed.
    """
    lines = text.splitlines()
    cleaned_lines = []

    # Detect headers and footers by tracking lines that repeat frequently
    header_footer_candidates = {}
    for line in lines:
        cleaned_line = line.strip()
        if cleaned_line:
            if cleaned_line in header_footer_candidates:
                header_footer_candidates[cleaned_line] += 1
            else:
                header_footer_candidates[cleaned_line] = 1

    # Determine the threshold: text appearing on more than 30% of the pages is likely a header/footer
    header_footer_threshold = max(2, int(0.3 * total_pages))

    # Identify and store all headers/footers
    headers_footers = set([line for line, count in header_footer_candidates.items() if count >= header_footer_threshold])

    # Clean the text by removing headers, footers, and page numbers
    for line in lines:
        stripped_line = line.strip()

        # Remove identified headers/footers
        if stripped_line in headers_footers:
            continue

        # Remove any page number patterns
        is_page_number = any(re.match(pattern, stripped_line) for pattern in page_number_patterns)
        if is_page_number:
            continue

        # Remove footer patterns (e.g., "530 | Chapter 12: The Future")
        is_footer = any(re.match(pattern, stripped_line) for pattern in footer_patterns)
        if is_footer:
            continue

        # If the line is neither a header/footer nor a page number, retain it
        cleaned_lines.append(line)

    return "\n".join(cleaned_lines)

# Function to clean and process the entire PDF
def clean_pdf_text(pdf_path):
    """
    Clean up headers, footers, and page numbers from each page of the PDF and combine into a single text file.

    Args:
    - pdf_path (str): Path to the PDF file.

    Returns:
    - cleaned_book_text (str): Combined cleaned text of the entire book.
    """
    doc = fitz.open(pdf_path)
    total_pages = len(doc)
    cleaned_book_text = ""  # Store the entire book's cleaned text

    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text = page.get_text("text")

        # Clean up headers, footers, and page numbers from the text
        cleaned_text = detect_and_remove_headers_footers(text, page_num, total_pages)
        cleaned_book_text += cleaned_text + "\n\n"  # Add cleaned text with spacing between pages

    return cleaned_book_text

# Function to save the entire cleaned book to a single text file
def save_cleaned_book(cleaned_text, pdf_path):
    """
    Save the cleaned text of the entire book into a single file named `book_cleaned.txt`.

    Args:
    - cleaned_text (str): Combined cleaned text of the entire book.
    - pdf_path (str): Path to the original PDF file for naming.
    """
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = "./cleaned_books"
    os.makedirs(output_dir, exist_ok=True)

    # Save the cleaned text into a single file named book_cleaned.txt
    cleaned_book_filename = os.path.join(output_dir, f"{book_name}_cleaned.txt")
    with open(cleaned_book_filename, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write(cleaned_text)
    print(f"Cleaned book saved as {cleaned_book_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
cleaned_book_text = clean_pdf_text(pdf_path)
save_cleaned_book(cleaned_book_text, pdf_path)
# Out:
# Cleaned book saved as ./cleaned_books\Designing Data Intensive Applications_cleaned.txt

# %%
import os
import re
import fitz  # PyMuPDF

# Define patterns for common page numbers
page_number_patterns = [
    r'^\s*\d+\s*$',                   # Simple page number: 1, 2, 3, ...
    r'^\s*Page \d+\s*$',              # Page 1, Page 2, ...
    r'^\s*Page \d+ of \d+\s*$',       # Page 1 of 50
    r'^\s*\d+\s*/\s*\d+\s*$',         # 1/50, 2/50, ...
    r'^\s*-\s*\d+\s*-\s*$',           # - 1 -, - 2 -, ...
    r'^\s*\d+\s*\|\s*$',              # 1 | (common in OCR PDFs)
]

# Helper function to detect headers and footers based on position and repetition
def detect_and_remove_headers_footers(text, page_num, total_pages, prev_footer=None):
    """
    Detect and clean up page numbers, headers, and footers in the given text using position and context.

    Args:
    - text (str): Text content of the page.
    - page_num (int): The current page number (0-based index).
    - total_pages (int): Total number of pages in the PDF.
    - prev_footer (str): Text of the previously detected footer, if any.

    Returns:
    - cleaned_text (str): Text with headers, footers, and page numbers removed.
    - footer_candidate (str): Detected footer text for this page, if found.
    """
    lines = text.splitlines()
    cleaned_lines = []
    footer_candidate = None

    # Detect the last line(s) as potential footers if they are repeated across multiple pages
    if len(lines) > 2:
        # Candidate for a footer is usually the last or second-to-last line
        footer_line = lines[-1].strip()
        second_last_line = lines[-2].strip()

        # Check if the last or second-to-last line matches a typical footer structure or repeats across pages
        is_page_number = any(re.match(pattern, footer_line) for pattern in page_number_patterns)
        if not is_page_number and prev_footer and footer_line.startswith(prev_footer.split()[0]):
            footer_candidate = footer_line

        # Similarly, check second-last line if it's not a footer already
        if not footer_candidate:
            is_page_number = any(re.match(pattern, second_last_line) for pattern in page_number_patterns)
            if not is_page_number and prev_footer and second_last_line.startswith(prev_footer.split()[0]):
                footer_candidate = second_last_line

    # Clean up headers, footers, and page numbers from the text
    for line in lines:
        stripped_line = line.strip()

        # Skip the identified footer candidate
        if footer_candidate and stripped_line == footer_candidate:
            continue

        # Remove any page number patterns
        is_page_number = any(re.match(pattern, stripped_line) for pattern in page_number_patterns)
        if is_page_number:
            continue

        # If the line is neither a header/footer nor a page number, retain it
        cleaned_lines.append(line)

    return "\n".join(cleaned_lines), footer_candidate

# Function to clean and process the entire PDF
def clean_pdf_text(pdf_path):
    """
    Clean up headers, footers, and page numbers from each page of the PDF and combine into a single text file.

    Args:
    - pdf_path (str): Path to the PDF file.

    Returns:
    - cleaned_book_text (str): Combined cleaned text of the entire book.
    """
    doc = fitz.open(pdf_path)
    total_pages = len(doc)
    cleaned_book_text = ""  # Store the entire book's cleaned text
    prev_footer = None      # Track the previously detected footer

    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text = page.get_text("text")

        # Clean up headers, footers, and page numbers from the text using context
        cleaned_text, footer_candidate = detect_and_remove_headers_footers(text, page_num, total_pages, prev_footer)
        prev_footer = footer_candidate if footer_candidate else prev_footer  # Update the footer candidate
        cleaned_book_text += cleaned_text + "\n\n"  # Add cleaned text with spacing between pages

    return cleaned_book_text

# Function to save the entire cleaned book to a single text file
def save_cleaned_book(cleaned_text, pdf_path):
    """
    Save the cleaned text of the entire book into a single file named `book_cleaned.txt`.

    Args:
    - cleaned_text (str): Combined cleaned text of the entire book.
    - pdf_path (str): Path to the original PDF file for naming.
    """
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = "./cleaned_books"
    os.makedirs(output_dir, exist_ok=True)

    # Save the cleaned text into a single file named book_cleaned.txt
    cleaned_book_filename = os.path.join(output_dir, f"{book_name}_cleaned.txt")
    with open(cleaned_book_filename, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write(cleaned_text)
    print(f"Cleaned book saved as {cleaned_book_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
cleaned_book_text = clean_pdf_text(pdf_path)
save_cleaned_book(cleaned_book_text, pdf_path)
# Out:
# Cleaned book saved as ./cleaned_books\Designing Data Intensive Applications_cleaned.txt

# %%
import os
import re
import fitz  # PyMuPDF

# Define patterns for common page numbers and header/footer markers
page_number_patterns = [
    r'^\s*\d+\s*$',                   # Simple page number: 1, 2, 3, ...
    r'^\s*Page \d+\s*$',              # Page 1, Page 2, ...
    r'^\s*Page \d+ of \d+\s*$',       # Page 1 of 50
    r'^\s*\d+\s*/\s*\d+\s*$',         # 1/50, 2/50, ...
    r'^\s*-\s*\d+\s*-\s*$',           # - 1 -, - 2 -, ...
    r'^\s*\d+\s*\|\s*$',              # 1 | (common in OCR PDFs)
]

# Function to analyze and clean headers and footers based on font size and patterns
def detect_and_remove_headers_footers(text_blocks, avg_font_size):
    """
    Detect and clean headers, footers, and page numbers using font size and position.

    Args:
    - text_blocks (list): List of text blocks from the page, including font size.
    - avg_font_size (float): Average font size in the document to differentiate headers/footers.

    Returns:
    - cleaned_text (str): Cleaned text for the page.
    """
    cleaned_lines = []

    # Iterate through each text block and decide if it's part of the main content or a header/footer
    for block in text_blocks:
        block_text = block[4].strip()  # Extract text content
        font_size = block[3]  # Font size is stored at index 3 in the block tuple
        y_position = block[1]  # Y-coordinate of the text block (position on the page)

        # Skip lines that match known page number patterns
        if any(re.match(pattern, block_text) for pattern in page_number_patterns):
            continue

        # If the font size is significantly smaller than the average font size, treat it as a header/footer
        if font_size < 0.8 * avg_font_size:
            continue

        # Retain lines that are likely part of the main content
        cleaned_lines.append(block_text)

    return "\n".join(cleaned_lines)

# Function to clean and process the entire PDF with font size analysis
def clean_pdf_text(pdf_path):
    """
    Clean up headers, footers, and page numbers from each page of the PDF using font size and position.

    Args:
    - pdf_path (str): Path to the PDF file.

    Returns:
    - cleaned_book_text (str): Combined cleaned text of the entire book.
    """
    doc = fitz.open(pdf_path)
    total_pages = len(doc)
    font_sizes = []  # Store font sizes to compute the average later
    cleaned_book_text = ""  # Store the entire book's cleaned text

    # First pass: gather font size information from all pages
    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Collect all font sizes to compute the average
        for block in text_blocks:
            font_sizes.append(block[3])  # Font size is stored at index 3 in the block tuple

    # Calculate the average font size in the document
    avg_font_size = sum(font_sizes) / len(font_sizes)

    # Second pass: clean each page based on font size and text patterns
    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Clean up headers, footers, and page numbers using font size
        cleaned_text = detect_and_remove_headers_footers(text_blocks, avg_font_size)
        cleaned_book_text += cleaned_text + "\n\n"  # Add cleaned text with spacing between pages

    return cleaned_book_text

# Function to save the entire cleaned book to a single text file
def save_cleaned_book(cleaned_text, pdf_path):
    """
    Save the cleaned text of the entire book into a single file named `book_cleaned.txt`.

    Args:
    - cleaned_text (str): Combined cleaned text of the entire book.
    - pdf_path (str): Path to the original PDF file for naming.
    """
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = "./cleaned_books"
    os.makedirs(output_dir, exist_ok=True)

    # Save the cleaned text into a single file named book_cleaned.txt
    cleaned_book_filename = os.path.join(output_dir, f"{book_name}_cleaned.txt")
    with open(cleaned_book_filename, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write(cleaned_text)
    print(f"Cleaned book saved as {cleaned_book_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
cleaned_book_text = clean_pdf_text(pdf_path)
save_cleaned_book(cleaned_book_text, pdf_path)
# Out:
# Cleaned book saved as ./cleaned_books\Designing Data Intensive Applications_cleaned.txt

# %%
import os
import re
import fitz  # PyMuPDF

# Define patterns for common page numbers and header/footer markers
page_number_patterns = [
    r'^\s*\d+\s*$',                   # Simple page number: 1, 2, 3, ...
    r'^\s*Page \d+\s*$',              # Page 1, Page 2, ...
    r'^\s*Page \d+ of \d+\s*$',       # Page 1 of 50
    r'^\s*\d+\s*/\s*\d+\s*$',         # 1/50, 2/50, ...
    r'^\s*-\s*\d+\s*-\s*$',           # - 1 -, - 2 -, ...
    r'^\s*\d+\s*\|\s*$',              # 1 | (common in OCR PDFs)
]

# Define a pattern for chapter-like footers that include page numbers
footer_pattern = re.compile(r'^\d+\s*\|\s*Chapter \d+.*')

# Function to analyze and clean headers and footers based on position and patterns
def detect_and_remove_headers_footers(text_blocks, avg_font_size):
    """
    Detect and clean headers, footers, and page numbers using font size and position.

    Args:
    - text_blocks (list): List of text blocks from the page, including font size.
    - avg_font_size (float): Average font size in the document to differentiate headers/footers.

    Returns:
    - cleaned_text (str): Cleaned text for the page.
    """
    cleaned_lines = []

    # Iterate through each text block and decide if it's part of the main content or a header/footer
    for block in text_blocks:
        block_text = block[4].strip()  # Extract text content
        font_size = block[3]  # Font size is stored at index 3 in the block tuple
        y_position = block[1]  # Y-coordinate of the text block (position on the page)

        # Skip lines that match known page number patterns or footer patterns
        if any(re.match(pattern, block_text) for pattern in page_number_patterns):
            continue
        if footer_pattern.match(block_text):
            continue

        # If the font size is significantly smaller than the average font size, treat it as a header/footer
        if font_size < 0.8 * avg_font_size:
            continue

        # Retain lines that are likely part of the main content
        cleaned_lines.append(block_text)

    return "\n".join(cleaned_lines)

# Function to clean and process the entire PDF with font size analysis
def clean_pdf_text(pdf_path):
    """
    Clean up headers, footers, and page numbers from each page of the PDF using font size and position.

    Args:
    - pdf_path (str): Path to the PDF file.

    Returns:
    - cleaned_book_text (str): Combined cleaned text of the entire book.
    """
    doc = fitz.open(pdf_path)
    total_pages = len(doc)
    font_sizes = []  # Store font sizes to compute the average later
    cleaned_book_text = ""  # Store the entire book's cleaned text

    # First pass: gather font size information from all pages
    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Collect all font sizes to compute the average
        for block in text_blocks:
            font_sizes.append(block[3])  # Font size is stored at index 3 in the block tuple

    # Calculate the average font size in the document
    avg_font_size = sum(font_sizes) / len(font_sizes)

    # Second pass: clean each page based on font size and text patterns
    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Clean up headers, footers, and page numbers using font size and position
        cleaned_text = detect_and_remove_headers_footers(text_blocks, avg_font_size)
        cleaned_book_text += cleaned_text + "\n\n"  # Add cleaned text with spacing between pages

    return cleaned_book_text

# Function to save the entire cleaned book to a single text file
def save_cleaned_book(cleaned_text, pdf_path):
    """
    Save the cleaned text of the entire book into a single file named `book_cleaned.txt`.

    Args:
    - cleaned_text (str): Combined cleaned text of the entire book.
    - pdf_path (str): Path to the original PDF file for naming.
    """
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = "./cleaned_books"
    os.makedirs(output_dir, exist_ok=True)

    # Save the cleaned text into a single file named book_cleaned.txt
    cleaned_book_filename = os.path.join(output_dir, f"{book_name}_cleaned.txt")
    with open(cleaned_book_filename, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write(cleaned_text)
    print(f"Cleaned book saved as {cleaned_book_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
cleaned_book_text = clean_pdf_text(pdf_path)
save_cleaned_book(cleaned_book_text, pdf_path)
# Out:
# Cleaned book saved as ./cleaned_books\Designing Data Intensive Applications_cleaned.txt

# %%
import os
import re
import fitz  # PyMuPDF

# Define patterns for common page numbers (optional)
page_number_patterns = [
    r'^\s*\d+\s*$',                   # Simple page number: 1, 2, 3, ...
    r'^\s*Page \d+\s*$',              # Page 1, Page 2, ...
    r'^\s*Page \d+ of \d+\s*$',       # Page 1 of 50
    r'^\s*\d+\s*/\s*\d+\s*$',         # 1/50, 2/50, ...
    r'^\s*-\s*\d+\s*-\s*$',           # - 1 -, - 2 -, ...
]

# Function to clean text based purely on font size
def clean_text_by_font_size(text_blocks, avg_font_size):
    """
    Clean the text based on font size. Consider text blocks significantly larger than the average as content
    and blocks significantly smaller as headers/footers.

    Args:
    - text_blocks (list): List of text blocks from the page, including font size.
    - avg_font_size (float): Average font size in the document.

    Returns:
    - cleaned_text (str): Cleaned text for the page.
    """
    cleaned_lines = []

    # Iterate through each text block and decide if it's part of the main content or a header/footer
    for block in text_blocks:
        block_text = block[4].strip()  # Extract text content
        font_size = block[3]  # Font size is stored at index 3 in the block tuple

        # Skip lines that match known page number patterns (optional)
        if any(re.match(pattern, block_text) for pattern in page_number_patterns):
            continue

        # Retain lines that have a font size close to or larger than the average
        if font_size >= 0.8 * avg_font_size:
            cleaned_lines.append(block_text)

    return "\n".join(cleaned_lines)

# Function to clean and process the entire PDF using font size analysis
def clean_pdf_text(pdf_path):
    """
    Clean up headers, footers, and page numbers from each page of the PDF using font size analysis.

    Args:
    - pdf_path (str): Path to the PDF file.

    Returns:
    - cleaned_book_text (str): Combined cleaned text of the entire book.
    """
    doc = fitz.open(pdf_path)
    total_pages = len(doc)
    font_sizes = []  # Store font sizes to compute the average later
    cleaned_book_text = ""  # Store the entire book's cleaned text

    # First pass: gather font size information from all pages
    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Collect all font sizes to compute the average
        for block in text_blocks:
            font_sizes.append(block[3])  # Font size is stored at index 3 in the block tuple

    # Calculate the average font size in the document
    avg_font_size = sum(font_sizes) / len(font_sizes)

    # Second pass: clean each page based on font size
    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Clean text using font size as the main heuristic
        cleaned_text = clean_text_by_font_size(text_blocks, avg_font_size)
        cleaned_book_text += cleaned_text + "\n\n"  # Add cleaned text with spacing between pages

    return cleaned_book_text

# Function to save the entire cleaned book to a single text file
def save_cleaned_book(cleaned_text, pdf_path):
    """
    Save the cleaned text of the entire book into a single file named `book_cleaned.txt`.

    Args:
    - cleaned_text (str): Combined cleaned text of the entire book.
    - pdf_path (str): Path to the original PDF file for naming.
    """
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = "./cleaned_books"
    os.makedirs(output_dir, exist_ok=True)

    # Save the cleaned text into a single file named book_cleaned.txt
    cleaned_book_filename = os.path.join(output_dir, f"{book_name}_cleaned.txt")
    with open(cleaned_book_filename, "w", encoding="utf-8") as cleaned_file:
        cleaned_file.write(cleaned_text)
    print(f"Cleaned book saved as {cleaned_book_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
cleaned_book_text = clean_pdf_text(pdf_path)
save_cleaned_book(cleaned_book_text, pdf_path)
# Out:
# Cleaned book saved as ./cleaned_books\Designing Data Intensive Applications_cleaned.txt

# %%
import fitz  # PyMuPDF
import os


def clean_pdf(pdf_path, output_path, stats):
    """
    Clean the PDF by removing headers, footers, and unnecessary page content.

    Args:
    - pdf_path (str): Path to the original PDF file.
    - output_path (str): Path to save the cleaned PDF.
    - stats (dict): Statistics dictionary from the PDF analyzer.

    Returns:
    - None
    """
    doc = fitz.open(pdf_path)
    total_pages = stats["total_pages"]

    # Set thresholds based on analysis to identify headers and footers
    min_body_font_size = stats["average_font_size"] - 2  # Assuming 2pt tolerance for body text
    max_body_font_size = stats["average_font_size"] + 2

    # Create a new PDF document to store cleaned content
    cleaned_doc = fitz.open()

    for page_num in range(total_pages):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("dict")["blocks"]

        # Create a new blank page in the cleaned PDF
        cleaned_page = cleaned_doc.new_page(width=page.rect.width, height=page.rect.height)

        for block in text_blocks:
            if block.get("type") != 0:  # Skip non-text blocks
                continue

            for line in block["lines"]:
                for span in line["spans"]:
                    font_size = span["size"]
                    text = span["text"].strip()
                    bbox = span["bbox"]

                    # Heuristic to remove headers and footers:
                    # 1. Exclude text with significantly different font sizes.
                    # 2. Remove text that appears in typical header/footer locations (e.g., top 10% or bottom 10% of the page).
                    # 3. Skip page numbers or common phrases found in headers/footers.
                    if (font_size < min_body_font_size or font_size > max_body_font_size or
                            bbox[1] < page.rect.height * 0.1 or bbox[3] > page.rect.height * 0.9 or
                            text.lower() in ["chapter", "page", "section"] or text.isdigit()):
                        continue

                    # If the text passes the filters, add it to the cleaned PDF page
                    cleaned_page.insert_text(
                        (bbox[0], bbox[1]),  # Position text at the original location
                        text,
                        fontsize=font_size,
                        fontname=span["font"],
                        color=(0, 0, 0)  # Keep the text in black color
                    )

    # Save the cleaned PDF
    cleaned_doc.save(output_path)
    cleaned_doc.close()
    doc.close()

    print(f"Cleaned PDF saved to {output_path}")


# Example usage with the analyzer's stats
pdf_path = "Designing Data Intensive Applications.pdf"
output_path = "Cleaned_Designing_Data_Intensive_Applications.pdf"
stats = analyze_pdf(pdf_path)
clean_pdf(pdf_path, output_path, stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 73
#      71 pdf_path = "Designing Data Intensive Applications.pdf"
#      72 output_path = "Cleaned_Designing_Data_Intensive_Applications.pdf"
# ---> 73 stats = analyze_pdf(pdf_path)
#      74 clean_pdf(pdf_path, output_path, stats)
#
# NameError: name 'analyze_pdf' is not defined
