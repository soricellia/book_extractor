# %%
# Install required libraries if not already installed
# !pip install PyPDF2

import os
from PyPDF2 import PdfReader

# Function to extract chapters and write them to separate files
def extract_chapters(pdf_path):
    # Get the book name from the file path
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = f"./books/{book_name}"
    
    # Create the directory for storing chapters if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Open the PDF file
    reader = PdfReader(pdf_path)
    
    # Initialize variables to hold chapter information
    chapter_start_indices = []
    chapters = []

    # Iterate over each page in the PDF and extract text
    for page_num, page in enumerate(reader.pages):
        text = page.extract_text()
        if text:
            # Check for the chapter title keyword ("Chapter")
            if "Chapter" in text:
                chapter_start_indices.append(page_num)

    # Add the last page index as the end boundary for the last chapter
    chapter_start_indices.append(len(reader.pages))
    
    # Extract each chapter based on the chapter indices
    for i in range(len(chapter_start_indices) - 1):
        start_page = chapter_start_indices[i]
        end_page = chapter_start_indices[i + 1]
        
        # Aggregate the text for the chapter
        chapter_text = ""
        for j in range(start_page, end_page):
            chapter_text += reader.pages[j].extract_text()
        
        # Write each chapter to a separate file
        chapter_filename = f"{output_dir}/chapter_{i+1}.txt"
        with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
            chapter_file.write(chapter_text)
        
        print(f"Chapter {i+1} written to {chapter_filename}")

# Input PDF file path
pdf_path = "Designing Data Intensive Applications.pdf"

# Extract chapters and write to separate files
extract_chapters(pdf_path)
# Out:
# Chapter 1 written to ./books/Designing Data Intensive Applications/chapter_1.txt
# Chapter 2 written to ./books/Designing Data Intensive Applications/chapter_2.txt
# Chapter 3 written to ./books/Designing Data Intensive Applications/chapter_3.txt
# Chapter 4 written to ./books/Designing Data Intensive Applications/chapter_4.txt
# Chapter 5 written to ./books/Designing Data Intensive Applications/chapter_5.txt
# Chapter 6 written to ./books/Designing Data Intensive Applications/chapter_6.txt
# Chapter 7 written to ./books/Designing Data Intensive Applications/chapter_7.txt
# Chapter 8 written to ./books/Designing Data Intensive Applications/chapter_8.txt
# Chapter 9 written to ./books/Designing Data Intensive Applications/chapter_9.txt
# Chapter 10 written to ./books/Designing Data Intensive Applications/chapter_10.txt
# Chapter 11 written to ./books/Designing Data Intensive Applications/chapter_11.txt
# Chapter 12 written to ./books/Designing Data Intensive Applications/chapter_12.txt
# Chapter 13 written to ./books/Designing Data Intensive Applications/chapter_13.txt
# Chapter 14 written to ./books/Designing Data Intensive Applications/chapter_14.txt
# Chapter 15 written to ./books/Designing Data Intensive Applications/chapter_15.txt
# Chapter 16 written to ./books/Designing Data Intensive Applications/chapter_16.txt
# Chapter 17 written to ./books/Designing Data Intensive Applications/chapter_17.txt
# Chapter 18 written to ./books/Designing Data Intensive Applications/chapter_18.txt
# Chapter 19 written to ./books/Designing Data Intensive Applications/chapter_19.txt
# Chapter 20 written to ./books/Designing Data Intensive Applications/chapter_20.txt
# Chapter 21 written to ./books/Designing Data Intensive Applications/chapter_21.txt
# Chapter 22 written to ./books/Designing Data Intensive Applications/chapter_22.txt
# Chapter 23 written to ./books/Designing Data Intensive Applications/chapter_23.txt
# Chapter 24 written to ./books/Designing Data Intensive Applications/chapter_24.txt
# Chapter 25 written to ./books/Designing Data Intensive Applications/chapter_25.txt
# Chapter 26 written to ./books/Designing Data Intensive Applications/chapter_26.txt
# Chapter 27 written to ./books/Designing Data Intensive Applications/chapter_27.txt
# Chapter 28 written to ./books/Designing Data Intensive Applications/chapter_28.txt
# Chapter 29 written to ./books/Designing Data Intensive Applications/chapter_29.txt
# Chapter 30 written to ./books/Designing Data Intensive Applications/chapter_30.txt
# Chapter 31 written to ./books/Designing Data Intensive Applications/chapter_31.txt
# Chapter 32 written to ./books/Designing Data Intensive Applications/chapter_32.txt
# Chapter 33 written to ./books/Designing Data Intensive Applications/chapter_33.txt
# Chapter 34 written to ./books/Designing Data Intensive Applications/chapter_34.txt
# Chapter 35 written to ./books/Designing Data Intensive Applications/chapter_35.txt
# Chapter 36 written to ./books/Designing Data Intensive Applications/chapter_36.txt
# Chapter 37 written to ./books/Designing Data Intensive Applications/chapter_37.txt
# Chapter 38 written to ./books/Designing Data Intensive Applications/chapter_38.txt
# Chapter 39 written to ./books/Designing Data Intensive Applications/chapter_39.txt
# Chapter 40 written to ./books/Designing Data Intensive Applications/chapter_40.txt
# Chapter 41 written to ./books/Designing Data Intensive Applications/chapter_41.txt
# Chapter 42 written to ./books/Designing Data Intensive Applications/chapter_42.txt
# Chapter 43 written to ./books/Designing Data Intensive Applications/chapter_43.txt
# Chapter 44 written to ./books/Designing Data Intensive Applications/chapter_44.txt
# Chapter 45 written to ./books/Designing Data Intensive Applications/chapter_45.txt
# Chapter 46 written to ./books/Designing Data Intensive Applications/chapter_46.txt
# Chapter 47 written to ./books/Designing Data Intensive Applications/chapter_47.txt
# Chapter 48 written to ./books/Designing Data Intensive Applications/chapter_48.txt
# Chapter 49 written to ./books/Designing Data Intensive Applications/chapter_49.txt
# Chapter 50 written to ./books/Designing Data Intensive Applications/chapter_50.txt
# Chapter 51 written to ./books/Designing Data Intensive Applications/chapter_51.txt
# Chapter 52 written to ./books/Designing Data Intensive Applications/chapter_52.txt
# Chapter 53 written to ./books/Designing Data Intensive Applications/chapter_53.txt
# Chapter 54 written to ./books/Designing Data Intensive Applications/chapter_54.txt
# Chapter 55 written to ./books/Designing Data Intensive Applications/chapter_55.txt
# Chapter 56 written to ./books/Designing Data Intensive Applications/chapter_56.txt
# Chapter 57 written to ./books/Designing Data Intensive Applications/chapter_57.txt
# Chapter 58 written to ./books/Designing Data Intensive Applications/chapter_58.txt
# Chapter 59 written to ./books/Designing Data Intensive Applications/chapter_59.txt
# Chapter 60 written to ./books/Designing Data Intensive Applications/chapter_60.txt
# Chapter 61 written to ./books/Designing Data Intensive Applications/chapter_61.txt
# Chapter 62 written to ./books/Designing Data Intensive Applications/chapter_62.txt
# Chapter 63 written to ./books/Designing Data Intensive Applications/chapter_63.txt
# Chapter 64 written to ./books/Designing Data Intensive Applications/chapter_64.txt
# Chapter 65 written to ./books/Designing Data Intensive Applications/chapter_65.txt
# Chapter 66 written to ./books/Designing Data Intensive Applications/chapter_66.txt
# Chapter 67 written to ./books/Designing Data Intensive Applications/chapter_67.txt
# Chapter 68 written to ./books/Designing Data Intensive Applications/chapter_68.txt
# Chapter 69 written to ./books/Designing Data Intensive Applications/chapter_69.txt
# Chapter 70 written to ./books/Designing Data Intensive Applications/chapter_70.txt
# Chapter 71 written to ./books/Designing Data Intensive Applications/chapter_71.txt
# Chapter 72 written to ./books/Designing Data Intensive Applications/chapter_72.txt
# Chapter 73 written to ./books/Designing Data Intensive Applications/chapter_73.txt
# Chapter 74 written to ./books/Designing Data Intensive Applications/chapter_74.txt
# Chapter 75 written to ./books/Designing Data Intensive Applications/chapter_75.txt
# Chapter 76 written to ./books/Designing Data Intensive Applications/chapter_76.txt
# Chapter 77 written to ./books/Designing Data Intensive Applications/chapter_77.txt
# Chapter 78 written to ./books/Designing Data Intensive Applications/chapter_78.txt
# Chapter 79 written to ./books/Designing Data Intensive Applications/chapter_79.txt
# Chapter 80 written to ./books/Designing Data Intensive Applications/chapter_80.txt
# Chapter 81 written to ./books/Designing Data Intensive Applications/chapter_81.txt
# Chapter 82 written to ./books/Designing Data Intensive Applications/chapter_82.txt
# Chapter 83 written to ./books/Designing Data Intensive Applications/chapter_83.txt
# Chapter 84 written to ./books/Designing Data Intensive Applications/chapter_84.txt
# Chapter 85 written to ./books/Designing Data Intensive Applications/chapter_85.txt
# Chapter 86 written to ./books/Designing Data Intensive Applications/chapter_86.txt
# Chapter 87 written to ./books/Designing Data Intensive Applications/chapter_87.txt
# Chapter 88 written to ./books/Designing Data Intensive Applications/chapter_88.txt
# Chapter 89 written to ./books/Designing Data Intensive Applications/chapter_89.txt
# Chapter 90 written to ./books/Designing Data Intensive Applications/chapter_90.txt
# Chapter 91 written to ./books/Designing Data Intensive Applications/chapter_91.txt
# Chapter 92 written to ./books/Designing Data Intensive Applications/chapter_92.txt
# Chapter 93 written to ./books/Designing Data Intensive Applications/chapter_93.txt
# Chapter 94 written to ./books/Designing Data Intensive Applications/chapter_94.txt
# Chapter 95 written to ./books/Designing Data Intensive Applications/chapter_95.txt
# Chapter 96 written to ./books/Designing Data Intensive Applications/chapter_96.txt
# Chapter 97 written to ./books/Designing Data Intensive Applications/chapter_97.txt
# Chapter 98 written to ./books/Designing Data Intensive Applications/chapter_98.txt
# Chapter 99 written to ./books/Designing Data Intensive Applications/chapter_99.txt
# Chapter 100 written to ./books/Designing Data Intensive Applications/chapter_100.txt
# Chapter 101 written to ./books/Designing Data Intensive Applications/chapter_101.txt
# Chapter 102 written to ./books/Designing Data Intensive Applications/chapter_102.txt
# Chapter 103 written to ./books/Designing Data Intensive Applications/chapter_103.txt
# Chapter 104 written to ./books/Designing Data Intensive Applications/chapter_104.txt
# Chapter 105 written to ./books/Designing Data Intensive Applications/chapter_105.txt
# Chapter 106 written to ./books/Designing Data Intensive Applications/chapter_106.txt
# Chapter 107 written to ./books/Designing Data Intensive Applications/chapter_107.txt
# Chapter 108 written to ./books/Designing Data Intensive Applications/chapter_108.txt
# Chapter 109 written to ./books/Designing Data Intensive Applications/chapter_109.txt
# Chapter 110 written to ./books/Designing Data Intensive Applications/chapter_110.txt
# Chapter 111 written to ./books/Designing Data Intensive Applications/chapter_111.txt
# Chapter 112 written to ./books/Designing Data Intensive Applications/chapter_112.txt
# Chapter 113 written to ./books/Designing Data Intensive Applications/chapter_113.txt
# Chapter 114 written to ./books/Designing Data Intensive Applications/chapter_114.txt
# Chapter 115 written to ./books/Designing Data Intensive Applications/chapter_115.txt
# Chapter 116 written to ./books/Designing Data Intensive Applications/chapter_116.txt
# Chapter 117 written to ./books/Designing Data Intensive Applications/chapter_117.txt
# Chapter 118 written to ./books/Designing Data Intensive Applications/chapter_118.txt
# Chapter 119 written to ./books/Designing Data Intensive Applications/chapter_119.txt
# Chapter 120 written to ./books/Designing Data Intensive Applications/chapter_120.txt
# Chapter 121 written to ./books/Designing Data Intensive Applications/chapter_121.txt
# Chapter 122 written to ./books/Designing Data Intensive Applications/chapter_122.txt
# Chapter 123 written to ./books/Designing Data Intensive Applications/chapter_123.txt
# Chapter 124 written to ./books/Designing Data Intensive Applications/chapter_124.txt
# Chapter 125 written to ./books/Designing Data Intensive Applications/chapter_125.txt
# Chapter 126 written to ./books/Designing Data Intensive Applications/chapter_126.txt
# Chapter 127 written to ./books/Designing Data Intensive Applications/chapter_127.txt
# Chapter 128 written to ./books/Designing Data Intensive Applications/chapter_128.txt
# Chapter 129 written to ./books/Designing Data Intensive Applications/chapter_129.txt
# Chapter 130 written to ./books/Designing Data Intensive Applications/chapter_130.txt
# Chapter 131 written to ./books/Designing Data Intensive Applications/chapter_131.txt
# Chapter 132 written to ./books/Designing Data Intensive Applications/chapter_132.txt
# Chapter 133 written to ./books/Designing Data Intensive Applications/chapter_133.txt
# Chapter 134 written to ./books/Designing Data Intensive Applications/chapter_134.txt
# Chapter 135 written to ./books/Designing Data Intensive Applications/chapter_135.txt
# Chapter 136 written to ./books/Designing Data Intensive Applications/chapter_136.txt
# Chapter 137 written to ./books/Designing Data Intensive Applications/chapter_137.txt
# Chapter 138 written to ./books/Designing Data Intensive Applications/chapter_138.txt
# Chapter 139 written to ./books/Designing Data Intensive Applications/chapter_139.txt
# Chapter 140 written to ./books/Designing Data Intensive Applications/chapter_140.txt
# Chapter 141 written to ./books/Designing Data Intensive Applications/chapter_141.txt
# Chapter 142 written to ./books/Designing Data Intensive Applications/chapter_142.txt
# Chapter 143 written to ./books/Designing Data Intensive Applications/chapter_143.txt
# Chapter 144 written to ./books/Designing Data Intensive Applications/chapter_144.txt
# Chapter 145 written to ./books/Designing Data Intensive Applications/chapter_145.txt
# Chapter 146 written to ./books/Designing Data Intensive Applications/chapter_146.txt
# Chapter 147 written to ./books/Designing Data Intensive Applications/chapter_147.txt
# Chapter 148 written to ./books/Designing Data Intensive Applications/chapter_148.txt
# Chapter 149 written to ./books/Designing Data Intensive Applications/chapter_149.txt
# Chapter 150 written to ./books/Designing Data Intensive Applications/chapter_150.txt
# Chapter 151 written to ./books/Designing Data Intensive Applications/chapter_151.txt
# Chapter 152 written to ./books/Designing Data Intensive Applications/chapter_152.txt
# Chapter 153 written to ./books/Designing Data Intensive Applications/chapter_153.txt
# Chapter 154 written to ./books/Designing Data Intensive Applications/chapter_154.txt
# Chapter 155 written to ./books/Designing Data Intensive Applications/chapter_155.txt
# Chapter 156 written to ./books/Designing Data Intensive Applications/chapter_156.txt
# Chapter 157 written to ./books/Designing Data Intensive Applications/chapter_157.txt
# Chapter 158 written to ./books/Designing Data Intensive Applications/chapter_158.txt
# Chapter 159 written to ./books/Designing Data Intensive Applications/chapter_159.txt
# Chapter 160 written to ./books/Designing Data Intensive Applications/chapter_160.txt
# Chapter 161 written to ./books/Designing Data Intensive Applications/chapter_161.txt
# Chapter 162 written to ./books/Designing Data Intensive Applications/chapter_162.txt
# Chapter 163 written to ./books/Designing Data Intensive Applications/chapter_163.txt
# Chapter 164 written to ./books/Designing Data Intensive Applications/chapter_164.txt
# Chapter 165 written to ./books/Designing Data Intensive Applications/chapter_165.txt
# Chapter 166 written to ./books/Designing Data Intensive Applications/chapter_166.txt
# Chapter 167 written to ./books/Designing Data Intensive Applications/chapter_167.txt
# Chapter 168 written to ./books/Designing Data Intensive Applications/chapter_168.txt
# Chapter 169 written to ./books/Designing Data Intensive Applications/chapter_169.txt
# Chapter 170 written to ./books/Designing Data Intensive Applications/chapter_170.txt
# Chapter 171 written to ./books/Designing Data Intensive Applications/chapter_171.txt
# Chapter 172 written to ./books/Designing Data Intensive Applications/chapter_172.txt
# Chapter 173 written to ./books/Designing Data Intensive Applications/chapter_173.txt
# Chapter 174 written to ./books/Designing Data Intensive Applications/chapter_174.txt
# Chapter 175 written to ./books/Designing Data Intensive Applications/chapter_175.txt
# Chapter 176 written to ./books/Designing Data Intensive Applications/chapter_176.txt
# Chapter 177 written to ./books/Designing Data Intensive Applications/chapter_177.txt
# Chapter 178 written to ./books/Designing Data Intensive Applications/chapter_178.txt
# Chapter 179 written to ./books/Designing Data Intensive Applications/chapter_179.txt
# Chapter 180 written to ./books/Designing Data Intensive Applications/chapter_180.txt
# Chapter 181 written to ./books/Designing Data Intensive Applications/chapter_181.txt
# Chapter 182 written to ./books/Designing Data Intensive Applications/chapter_182.txt
# Chapter 183 written to ./books/Designing Data Intensive Applications/chapter_183.txt
# Chapter 184 written to ./books/Designing Data Intensive Applications/chapter_184.txt
# Chapter 185 written to ./books/Designing Data Intensive Applications/chapter_185.txt
# Chapter 186 written to ./books/Designing Data Intensive Applications/chapter_186.txt
# Chapter 187 written to ./books/Designing Data Intensive Applications/chapter_187.txt
# Chapter 188 written to ./books/Designing Data Intensive Applications/chapter_188.txt
# Chapter 189 written to ./books/Designing Data Intensive Applications/chapter_189.txt
# Chapter 190 written to ./books/Designing Data Intensive Applications/chapter_190.txt
# Chapter 191 written to ./books/Designing Data Intensive Applications/chapter_191.txt
# Chapter 192 written to ./books/Designing Data Intensive Applications/chapter_192.txt
# Chapter 193 written to ./books/Designing Data Intensive Applications/chapter_193.txt
# Chapter 194 written to ./books/Designing Data Intensive Applications/chapter_194.txt
# Chapter 195 written to ./books/Designing Data Intensive Applications/chapter_195.txt
# Chapter 196 written to ./books/Designing Data Intensive Applications/chapter_196.txt
# Chapter 197 written to ./books/Designing Data Intensive Applications/chapter_197.txt
# Chapter 198 written to ./books/Designing Data Intensive Applications/chapter_198.txt
# Chapter 199 written to ./books/Designing Data Intensive Applications/chapter_199.txt
# Chapter 200 written to ./books/Designing Data Intensive Applications/chapter_200.txt
# Chapter 201 written to ./books/Designing Data Intensive Applications/chapter_201.txt
# Chapter 202 written to ./books/Designing Data Intensive Applications/chapter_202.txt
# Chapter 203 written to ./books/Designing Data Intensive Applications/chapter_203.txt
# Chapter 204 written to ./books/Designing Data Intensive Applications/chapter_204.txt
# Chapter 205 written to ./books/Designing Data Intensive Applications/chapter_205.txt
# Chapter 206 written to ./books/Designing Data Intensive Applications/chapter_206.txt
# Chapter 207 written to ./books/Designing Data Intensive Applications/chapter_207.txt
# Chapter 208 written to ./books/Designing Data Intensive Applications/chapter_208.txt
# Chapter 209 written to ./books/Designing Data Intensive Applications/chapter_209.txt
# Chapter 210 written to ./books/Designing Data Intensive Applications/chapter_210.txt
# Chapter 211 written to ./books/Designing Data Intensive Applications/chapter_211.txt
# Chapter 212 written to ./books/Designing Data Intensive Applications/chapter_212.txt
# Chapter 213 written to ./books/Designing Data Intensive Applications/chapter_213.txt
# Chapter 214 written to ./books/Designing Data Intensive Applications/chapter_214.txt
# Chapter 215 written to ./books/Designing Data Intensive Applications/chapter_215.txt
# Chapter 216 written to ./books/Designing Data Intensive Applications/chapter_216.txt
# Chapter 217 written to ./books/Designing Data Intensive Applications/chapter_217.txt
# Chapter 218 written to ./books/Designing Data Intensive Applications/chapter_218.txt
# Chapter 219 written to ./books/Designing Data Intensive Applications/chapter_219.txt
# Chapter 220 written to ./books/Designing Data Intensive Applications/chapter_220.txt
# Chapter 221 written to ./books/Designing Data Intensive Applications/chapter_221.txt
# Chapter 222 written to ./books/Designing Data Intensive Applications/chapter_222.txt
# Chapter 223 written to ./books/Designing Data Intensive Applications/chapter_223.txt
# Chapter 224 written to ./books/Designing Data Intensive Applications/chapter_224.txt
# Chapter 225 written to ./books/Designing Data Intensive Applications/chapter_225.txt
# Chapter 226 written to ./books/Designing Data Intensive Applications/chapter_226.txt
# Chapter 227 written to ./books/Designing Data Intensive Applications/chapter_227.txt
# Chapter 228 written to ./books/Designing Data Intensive Applications/chapter_228.txt
# Chapter 229 written to ./books/Designing Data Intensive Applications/chapter_229.txt
# Chapter 230 written to ./books/Designing Data Intensive Applications/chapter_230.txt
# Chapter 231 written to ./books/Designing Data Intensive Applications/chapter_231.txt
# Chapter 232 written to ./books/Designing Data Intensive Applications/chapter_232.txt
# Chapter 233 written to ./books/Designing Data Intensive Applications/chapter_233.txt
# Chapter 234 written to ./books/Designing Data Intensive Applications/chapter_234.txt
# Chapter 235 written to ./books/Designing Data Intensive Applications/chapter_235.txt
# Chapter 236 written to ./books/Designing Data Intensive Applications/chapter_236.txt
# Chapter 237 written to ./books/Designing Data Intensive Applications/chapter_237.txt
# Chapter 238 written to ./books/Designing Data Intensive Applications/chapter_238.txt
# Chapter 239 written to ./books/Designing Data Intensive Applications/chapter_239.txt
# Chapter 240 written to ./books/Designing Data Intensive Applications/chapter_240.txt
# Chapter 241 written to ./books/Designing Data Intensive Applications/chapter_241.txt
# Chapter 242 written to ./books/Designing Data Intensive Applications/chapter_242.txt
# Chapter 243 written to ./books/Designing Data Intensive Applications/chapter_243.txt
# Chapter 244 written to ./books/Designing Data Intensive Applications/chapter_244.txt
# Chapter 245 written to ./books/Designing Data Intensive Applications/chapter_245.txt
# Chapter 246 written to ./books/Designing Data Intensive Applications/chapter_246.txt
# Chapter 247 written to ./books/Designing Data Intensive Applications/chapter_247.txt
# Chapter 248 written to ./books/Designing Data Intensive Applications/chapter_248.txt
# Chapter 249 written to ./books/Designing Data Intensive Applications/chapter_249.txt
# Chapter 250 written to ./books/Designing Data Intensive Applications/chapter_250.txt
# Chapter 251 written to ./books/Designing Data Intensive Applications/chapter_251.txt
# Chapter 252 written to ./books/Designing Data Intensive Applications/chapter_252.txt
# Chapter 253 written to ./books/Designing Data Intensive Applications/chapter_253.txt
# Chapter 254 written to ./books/Designing Data Intensive Applications/chapter_254.txt
# Chapter 255 written to ./books/Designing Data Intensive Applications/chapter_255.txt
# Chapter 256 written to ./books/Designing Data Intensive Applications/chapter_256.txt
# Chapter 257 written to ./books/Designing Data Intensive Applications/chapter_257.txt
# Chapter 258 written to ./books/Designing Data Intensive Applications/chapter_258.txt
# Chapter 259 written to ./books/Designing Data Intensive Applications/chapter_259.txt
# Chapter 260 written to ./books/Designing Data Intensive Applications/chapter_260.txt
# Chapter 261 written to ./books/Designing Data Intensive Applications/chapter_261.txt
# Chapter 262 written to ./books/Designing Data Intensive Applications/chapter_262.txt
# Chapter 263 written to ./books/Designing Data Intensive Applications/chapter_263.txt
# Chapter 264 written to ./books/Designing Data Intensive Applications/chapter_264.txt
# Chapter 265 written to ./books/Designing Data Intensive Applications/chapter_265.txt
# Chapter 266 written to ./books/Designing Data Intensive Applications/chapter_266.txt
# Chapter 267 written to ./books/Designing Data Intensive Applications/chapter_267.txt
# Chapter 268 written to ./books/Designing Data Intensive Applications/chapter_268.txt
# Chapter 269 written to ./books/Designing Data Intensive Applications/chapter_269.txt
# Chapter 270 written to ./books/Designing Data Intensive Applications/chapter_270.txt
# Chapter 271 written to ./books/Designing Data Intensive Applications/chapter_271.txt
# Chapter 272 written to ./books/Designing Data Intensive Applications/chapter_272.txt
# Chapter 273 written to ./books/Designing Data Intensive Applications/chapter_273.txt
# Chapter 274 written to ./books/Designing Data Intensive Applications/chapter_274.txt
# Chapter 275 written to ./books/Designing Data Intensive Applications/chapter_275.txt
# Chapter 276 written to ./books/Designing Data Intensive Applications/chapter_276.txt
# Chapter 277 written to ./books/Designing Data Intensive Applications/chapter_277.txt
# Chapter 278 written to ./books/Designing Data Intensive Applications/chapter_278.txt
# Chapter 279 written to ./books/Designing Data Intensive Applications/chapter_279.txt
# Chapter 280 written to ./books/Designing Data Intensive Applications/chapter_280.txt
# Chapter 281 written to ./books/Designing Data Intensive Applications/chapter_281.txt
# Chapter 282 written to ./books/Designing Data Intensive Applications/chapter_282.txt
# Chapter 283 written to ./books/Designing Data Intensive Applications/chapter_283.txt
# Chapter 284 written to ./books/Designing Data Intensive Applications/chapter_284.txt
# Chapter 285 written to ./books/Designing Data Intensive Applications/chapter_285.txt
# Chapter 286 written to ./books/Designing Data Intensive Applications/chapter_286.txt
# Chapter 287 written to ./books/Designing Data Intensive Applications/chapter_287.txt
# Chapter 288 written to ./books/Designing Data Intensive Applications/chapter_288.txt
# Chapter 289 written to ./books/Designing Data Intensive Applications/chapter_289.txt
# Chapter 290 written to ./books/Designing Data Intensive Applications/chapter_290.txt
# Chapter 291 written to ./books/Designing Data Intensive Applications/chapter_291.txt
# Chapter 292 written to ./books/Designing Data Intensive Applications/chapter_292.txt
# Chapter 293 written to ./books/Designing Data Intensive Applications/chapter_293.txt
# Chapter 294 written to ./books/Designing Data Intensive Applications/chapter_294.txt
# Chapter 295 written to ./books/Designing Data Intensive Applications/chapter_295.txt
# Chapter 296 written to ./books/Designing Data Intensive Applications/chapter_296.txt
# Chapter 297 written to ./books/Designing Data Intensive Applications/chapter_297.txt
# Chapter 298 written to ./books/Designing Data Intensive Applications/chapter_298.txt
# Chapter 299 written to ./books/Designing Data Intensive Applications/chapter_299.txt
# Chapter 300 written to ./books/Designing Data Intensive Applications/chapter_300.txt
# Chapter 301 written to ./books/Designing Data Intensive Applications/chapter_301.txt
# Chapter 302 written to ./books/Designing Data Intensive Applications/chapter_302.txt
# Chapter 303 written to ./books/Designing Data Intensive Applications/chapter_303.txt
# Chapter 304 written to ./books/Designing Data Intensive Applications/chapter_304.txt
# Chapter 305 written to ./books/Designing Data Intensive Applications/chapter_305.txt
# Chapter 306 written to ./books/Designing Data Intensive Applications/chapter_306.txt
# Chapter 307 written to ./books/Designing Data Intensive Applications/chapter_307.txt
# Chapter 308 written to ./books/Designing Data Intensive Applications/chapter_308.txt
# Chapter 309 written to ./books/Designing Data Intensive Applications/chapter_309.txt
# Chapter 310 written to ./books/Designing Data Intensive Applications/chapter_310.txt
# Chapter 311 written to ./books/Designing Data Intensive Applications/chapter_311.txt
# Chapter 312 written to ./books/Designing Data Intensive Applications/chapter_312.txt
# Chapter 313 written to ./books/Designing Data Intensive Applications/chapter_313.txt
# Chapter 314 written to ./books/Designing Data Intensive Applications/chapter_314.txt
# Chapter 315 written to ./books/Designing Data Intensive Applications/chapter_315.txt
# Chapter 316 written to ./books/Designing Data Intensive Applications/chapter_316.txt
# Chapter 317 written to ./books/Designing Data Intensive Applications/chapter_317.txt
# Chapter 318 written to ./books/Designing Data Intensive Applications/chapter_318.txt
# Chapter 319 written to ./books/Designing Data Intensive Applications/chapter_319.txt
# Chapter 320 written to ./books/Designing Data Intensive Applications/chapter_320.txt
# Chapter 321 written to ./books/Designing Data Intensive Applications/chapter_321.txt
# Chapter 322 written to ./books/Designing Data Intensive Applications/chapter_322.txt
# Chapter 323 written to ./books/Designing Data Intensive Applications/chapter_323.txt
# Chapter 324 written to ./books/Designing Data Intensive Applications/chapter_324.txt
# Chapter 325 written to ./books/Designing Data Intensive Applications/chapter_325.txt
# Chapter 326 written to ./books/Designing Data Intensive Applications/chapter_326.txt

# %%
# version 2

import os
import fitz  # PyMuPDF

# Helper function to extract text and analyze styles
def analyze_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    chapters = []

    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")
        chapter_candidates = []

        # Analyze each text block
        for block in text_blocks:
            block_text = block[4].strip()
            if not block_text:
                continue

            # Extract font size and position
            font_size = block[3]  # Extract font size
            bbox = block[:4]  # bounding box (x0, y0, x1, y1)

            # Check for chapter patterns and large font sizes
            if ("chapter" in block_text.lower()) or (font_size > 12):
                chapter_candidates.append((block_text, page_num, font_size, bbox))

        # Determine the highest scoring chapter candidate (if any)
        if chapter_candidates:
            chapter_candidates.sort(key=lambda x: -x[2])  # Sort by font size descending
            chapters.append((chapter_candidates[0][1], chapter_candidates[0][0]))  # Store the page number and text

    return chapters

# Function to extract chapters and write to separate files
def extract_chapters_with_analysis(pdf_path):
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = f"./books/{book_name}"
    os.makedirs(output_dir, exist_ok=True)

    chapters = analyze_pdf(pdf_path)

    doc = fitz.open(pdf_path)
    for i, (start_page, chapter_title) in enumerate(chapters):
        if i + 1 < len(chapters):
            end_page = chapters[i + 1][0]
        else:
            end_page = len(doc)

        chapter_text = ""
        for page_num in range(start_page, end_page):
            page = doc.load_page(page_num)
            chapter_text += page.get_text("text")

        chapter_filename = f"{output_dir}/chapter_{i+1}.txt"
        with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
            chapter_file.write(chapter_text)
        print(f"Chapter {i+1} ('{chapter_title}') written to {chapter_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
extract_chapters_with_analysis(pdf_path)
# Out:
# Chapter 1 ('Martin Kleppmann') written to ./books/Designing Data Intensive Applications/chapter_1.txt
# Chapter 2 ('Boston
# Farnham
# Sebastopol
# Tokyo
# Beijing
# Boston
# Farnham
# Sebastopol
# Tokyo
# Beijing') written to ./books/Designing Data Intensive Applications/chapter_2.txt
# Chapter 3 ('[LSI]') written to ./books/Designing Data Intensive Applications/chapter_3.txt
# Chapter 4 ('Technology is a powerful force in our society. Data, software, and communication can
# be used for bad: to entrench unfair power structures, to undermine human rights, and
# to protect vested interests. But they can also be used for good: to make underrepresented
# people’s voices heard, to create opportunities for everyone, and to avert disasters. This
# book is dedicated to everyone working toward the good.') written to ./books/Designing Data Intensive Applications/chapter_4.txt
# Chapter 5 ('Computing is pop culture. […] Pop culture holds a disdain for history. Pop culture is all
# about identity and feeling like you’re participating. It has nothing to do with cooperation,
# the past or the future—it’s living in the present. I think the same is true of most people who
# write code for money. They have no idea where [their culture came from].
# —Alan Kay, in interview with Dr Dobb’s Journal (2012)') written to ./books/Designing Data Intensive Applications/chapter_5.txt
# Chapter 6 ('vii') written to ./books/Designing Data Intensive Applications/chapter_6.txt
# Chapter 7 ('viii
# |
# Table of Contents') written to ./books/Designing Data Intensive Applications/chapter_7.txt
# Chapter 8 ('Table of Contents
# |
# ix') written to ./books/Designing Data Intensive Applications/chapter_8.txt
# Chapter 9 ('x
# |
# Table of Contents') written to ./books/Designing Data Intensive Applications/chapter_9.txt
# Chapter 10 ('Table of Contents
# |
# xi') written to ./books/Designing Data Intensive Applications/chapter_10.txt
# Chapter 11 ('xii
# |
# Table of Contents') written to ./books/Designing Data Intensive Applications/chapter_11.txt
# Chapter 12 ('Preface
# |
# xiii') written to ./books/Designing Data Intensive Applications/chapter_12.txt
# Chapter 13 ('xiv
# |
# Preface') written to ./books/Designing Data Intensive Applications/chapter_13.txt
# Chapter 14 ('Preface
# |
# xv') written to ./books/Designing Data Intensive Applications/chapter_14.txt
# Chapter 15 ('xvi
# |
# Preface') written to ./books/Designing Data Intensive Applications/chapter_15.txt
# Chapter 16 ('Preface
# |
# xvii') written to ./books/Designing Data Intensive Applications/chapter_16.txt
# Chapter 17 ('xviii
# |
# Preface') written to ./books/Designing Data Intensive Applications/chapter_17.txt
# Chapter 18 ('Preface
# |
# xix') written to ./books/Designing Data Intensive Applications/chapter_18.txt
# Chapter 19 ('Later, Part II will turn to the particular issues of distributed data systems.') written to ./books/Designing Data Intensive Applications/chapter_19.txt
# Chapter 20 ('3') written to ./books/Designing Data Intensive Applications/chapter_20.txt
# Chapter 21 ('4
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_21.txt
# Chapter 22 ('Thinking About Data Systems
# |
# 5') written to ./books/Designing Data Intensive Applications/chapter_22.txt
# Chapter 23 ('6
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_23.txt
# Chapter 24 ('Reliability
# |
# 7') written to ./books/Designing Data Intensive Applications/chapter_24.txt
# Chapter 25 ('8
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_25.txt
# Chapter 26 ('Reliability
# |
# 9') written to ./books/Designing Data Intensive Applications/chapter_26.txt
# Chapter 27 ('10
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_27.txt
# Chapter 28 ('Scalability
# |
# 11') written to ./books/Designing Data Intensive Applications/chapter_28.txt
# Chapter 29 ('12
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_29.txt
# Chapter 30 ('Scalability
# |
# 13') written to ./books/Designing Data Intensive Applications/chapter_30.txt
# Chapter 31 ('14
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_31.txt
# Chapter 32 ('Scalability
# |
# 15') written to ./books/Designing Data Intensive Applications/chapter_32.txt
# Chapter 33 ('16
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_33.txt
# Chapter 34 ('Scalability
# |
# 17') written to ./books/Designing Data Intensive Applications/chapter_34.txt
# Chapter 35 ('18
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_35.txt
# Chapter 36 ('Maintainability
# |
# 19') written to ./books/Designing Data Intensive Applications/chapter_36.txt
# Chapter 37 ('20
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_37.txt
# Chapter 38 ('Maintainability
# |
# 21') written to ./books/Designing Data Intensive Applications/chapter_38.txt
# Chapter 39 ('22
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_39.txt
# Chapter 40 ('Summary
# |
# 23') written to ./books/Designing Data Intensive Applications/chapter_40.txt
# Chapter 41 ('24
# |
# Chapter 1: Reliable, Scalable, and Maintainable Applications') written to ./books/Designing Data Intensive Applications/chapter_41.txt
# Chapter 42 ('Summary
# |
# 25') written to ./books/Designing Data Intensive Applications/chapter_42.txt
# Chapter 43 ('27') written to ./books/Designing Data Intensive Applications/chapter_43.txt
# Chapter 44 ('28
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_44.txt
# Chapter 45 ('Relational Model Versus Document Model
# |
# 29') written to ./books/Designing Data Intensive Applications/chapter_45.txt
# Chapter 46 ('30
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_46.txt
# Chapter 47 ('Relational Model Versus Document Model
# |
# 31') written to ./books/Designing Data Intensive Applications/chapter_47.txt
# Chapter 48 ('32
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_48.txt
# Chapter 49 ('Relational Model Versus Document Model
# |
# 33') written to ./books/Designing Data Intensive Applications/chapter_49.txt
# Chapter 50 ('34
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_50.txt
# Chapter 51 ('Relational Model Versus Document Model
# |
# 35') written to ./books/Designing Data Intensive Applications/chapter_51.txt
# Chapter 52 ('36
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_52.txt
# Chapter 53 ('Relational Model Versus Document Model
# |
# 37') written to ./books/Designing Data Intensive Applications/chapter_53.txt
# Chapter 54 ('38
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_54.txt
# Chapter 55 ('Relational Model Versus Document Model
# |
# 39') written to ./books/Designing Data Intensive Applications/chapter_55.txt
# Chapter 56 ('40
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_56.txt
# Chapter 57 ('Relational Model Versus Document Model
# |
# 41') written to ./books/Designing Data Intensive Applications/chapter_57.txt
# Chapter 58 ('42
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_58.txt
# Chapter 59 ('Query Languages for Data
# |
# 43') written to ./books/Designing Data Intensive Applications/chapter_59.txt
# Chapter 60 ('44
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_60.txt
# Chapter 61 ('Query Languages for Data
# |
# 45') written to ./books/Designing Data Intensive Applications/chapter_61.txt
# Chapter 62 ('46
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_62.txt
# Chapter 63 ('Query Languages for Data
# |
# 47') written to ./books/Designing Data Intensive Applications/chapter_63.txt
# Chapter 64 ('48
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_64.txt
# Chapter 65 ('Graph-Like Data Models
# |
# 49') written to ./books/Designing Data Intensive Applications/chapter_65.txt
# Chapter 66 ('50
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_66.txt
# Chapter 67 ('Graph-Like Data Models
# |
# 51') written to ./books/Designing Data Intensive Applications/chapter_67.txt
# Chapter 68 ('52
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_68.txt
# Chapter 69 ('Graph-Like Data Models
# |
# 53') written to ./books/Designing Data Intensive Applications/chapter_69.txt
# Chapter 70 ('54
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_70.txt
# Chapter 71 ('Graph-Like Data Models
# |
# 55') written to ./books/Designing Data Intensive Applications/chapter_71.txt
# Chapter 72 ('56
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_72.txt
# Chapter 73 ('Graph-Like Data Models
# |
# 57') written to ./books/Designing Data Intensive Applications/chapter_73.txt
# Chapter 74 ('58
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_74.txt
# Chapter 75 ('Graph-Like Data Models
# |
# 59') written to ./books/Designing Data Intensive Applications/chapter_75.txt
# Chapter 76 ('60
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_76.txt
# Chapter 77 ('Graph-Like Data Models
# |
# 61') written to ./books/Designing Data Intensive Applications/chapter_77.txt
# Chapter 78 ('62
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_78.txt
# Chapter 79 ('Summary
# |
# 63') written to ./books/Designing Data Intensive Applications/chapter_79.txt
# Chapter 80 ('64
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_80.txt
# Chapter 81 ('Summary
# |
# 65') written to ./books/Designing Data Intensive Applications/chapter_81.txt
# Chapter 82 ('66
# |
# Chapter 2: Data Models and Query Languages') written to ./books/Designing Data Intensive Applications/chapter_82.txt
# Chapter 83 ('Summary
# |
# 67') written to ./books/Designing Data Intensive Applications/chapter_83.txt
# Chapter 84 ('69') written to ./books/Designing Data Intensive Applications/chapter_84.txt
# Chapter 85 ('70
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_85.txt
# Chapter 86 ('Data Structures That Power Your Database
# |
# 71') written to ./books/Designing Data Intensive Applications/chapter_86.txt
# Chapter 87 ('72
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_87.txt
# Chapter 88 ('Data Structures That Power Your Database
# |
# 73') written to ./books/Designing Data Intensive Applications/chapter_88.txt
# Chapter 89 ('74
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_89.txt
# Chapter 90 ('Data Structures That Power Your Database
# |
# 75') written to ./books/Designing Data Intensive Applications/chapter_90.txt
# Chapter 91 ('76
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_91.txt
# Chapter 92 ('Data Structures That Power Your Database
# |
# 77') written to ./books/Designing Data Intensive Applications/chapter_92.txt
# Chapter 93 ('78
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_93.txt
# Chapter 94 ('Data Structures That Power Your Database
# |
# 79') written to ./books/Designing Data Intensive Applications/chapter_94.txt
# Chapter 95 ('80
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_95.txt
# Chapter 96 ('Data Structures That Power Your Database
# |
# 81') written to ./books/Designing Data Intensive Applications/chapter_96.txt
# Chapter 97 ('82
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_97.txt
# Chapter 98 ('Data Structures That Power Your Database
# |
# 83') written to ./books/Designing Data Intensive Applications/chapter_98.txt
# Chapter 99 ('84
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_99.txt
# Chapter 100 ('Data Structures That Power Your Database
# |
# 85') written to ./books/Designing Data Intensive Applications/chapter_100.txt
# Chapter 101 ('86
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_101.txt
# Chapter 102 ('Data Structures That Power Your Database
# |
# 87') written to ./books/Designing Data Intensive Applications/chapter_102.txt
# Chapter 103 ('88
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_103.txt
# Chapter 104 ('Data Structures That Power Your Database
# |
# 89') written to ./books/Designing Data Intensive Applications/chapter_104.txt
# Chapter 105 ('90
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_105.txt
# Chapter 106 ('Transaction Processing or Analytics?
# |
# 91') written to ./books/Designing Data Intensive Applications/chapter_106.txt
# Chapter 107 ('92
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_107.txt
# Chapter 108 ('Transaction Processing or Analytics?
# |
# 93') written to ./books/Designing Data Intensive Applications/chapter_108.txt
# Chapter 109 ('94
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_109.txt
# Chapter 110 ('Column-Oriented Storage
# |
# 95') written to ./books/Designing Data Intensive Applications/chapter_110.txt
# Chapter 111 ('96
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_111.txt
# Chapter 112 ('Column-Oriented Storage
# |
# 97') written to ./books/Designing Data Intensive Applications/chapter_112.txt
# Chapter 113 ('98
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_113.txt
# Chapter 114 ('Column-Oriented Storage
# |
# 99') written to ./books/Designing Data Intensive Applications/chapter_114.txt
# Chapter 115 ('100
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_115.txt
# Chapter 116 ('Column-Oriented Storage
# |
# 101') written to ./books/Designing Data Intensive Applications/chapter_116.txt
# Chapter 117 ('102
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_117.txt
# Chapter 118 ('Summary
# |
# 103') written to ./books/Designing Data Intensive Applications/chapter_118.txt
# Chapter 119 ('104
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_119.txt
# Chapter 120 ('Summary
# |
# 105') written to ./books/Designing Data Intensive Applications/chapter_120.txt
# Chapter 121 ('106
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_121.txt
# Chapter 122 ('Summary
# |
# 107') written to ./books/Designing Data Intensive Applications/chapter_122.txt
# Chapter 123 ('108
# |
# Chapter 3: Storage and Retrieval') written to ./books/Designing Data Intensive Applications/chapter_123.txt
# Chapter 124 ('111') written to ./books/Designing Data Intensive Applications/chapter_124.txt
# Chapter 125 ('112
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_125.txt
# Chapter 126 ('Formats for Encoding Data
# |
# 113') written to ./books/Designing Data Intensive Applications/chapter_126.txt
# Chapter 127 ('114
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_127.txt
# Chapter 128 ('Formats for Encoding Data
# |
# 115') written to ./books/Designing Data Intensive Applications/chapter_128.txt
# Chapter 129 ('116
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_129.txt
# Chapter 130 ('Formats for Encoding Data
# |
# 117') written to ./books/Designing Data Intensive Applications/chapter_130.txt
# Chapter 131 ('118
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_131.txt
# Chapter 132 ('Formats for Encoding Data
# |
# 119') written to ./books/Designing Data Intensive Applications/chapter_132.txt
# Chapter 133 ('120
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_133.txt
# Chapter 134 ('Formats for Encoding Data
# |
# 121') written to ./books/Designing Data Intensive Applications/chapter_134.txt
# Chapter 135 ('122
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_135.txt
# Chapter 136 ('Formats for Encoding Data
# |
# 123') written to ./books/Designing Data Intensive Applications/chapter_136.txt
# Chapter 137 ('124
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_137.txt
# Chapter 138 ('Formats for Encoding Data
# |
# 125') written to ./books/Designing Data Intensive Applications/chapter_138.txt
# Chapter 139 ('126
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_139.txt
# Chapter 140 ('Formats for Encoding Data
# |
# 127') written to ./books/Designing Data Intensive Applications/chapter_140.txt
# Chapter 141 ('128
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_141.txt
# Chapter 142 ('Modes of Dataflow
# |
# 129') written to ./books/Designing Data Intensive Applications/chapter_142.txt
# Chapter 143 ('130
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_143.txt
# Chapter 144 ('Modes of Dataflow
# |
# 131') written to ./books/Designing Data Intensive Applications/chapter_144.txt
# Chapter 145 ('132
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_145.txt
# Chapter 146 ('Modes of Dataflow
# |
# 133') written to ./books/Designing Data Intensive Applications/chapter_146.txt
# Chapter 147 ('134
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_147.txt
# Chapter 148 ('Modes of Dataflow
# |
# 135') written to ./books/Designing Data Intensive Applications/chapter_148.txt
# Chapter 149 ('136
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_149.txt
# Chapter 150 ('Modes of Dataflow
# |
# 137') written to ./books/Designing Data Intensive Applications/chapter_150.txt
# Chapter 151 ('138
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_151.txt
# Chapter 152 ('Summary
# |
# 139') written to ./books/Designing Data Intensive Applications/chapter_152.txt
# Chapter 153 ('140
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_153.txt
# Chapter 154 ('Summary
# |
# 141') written to ./books/Designing Data Intensive Applications/chapter_154.txt
# Chapter 155 ('142
# |
# Chapter 4: Encoding and Evolution') written to ./books/Designing Data Intensive Applications/chapter_155.txt
# Chapter 156 ('Summary
# |
# 143') written to ./books/Designing Data Intensive Applications/chapter_156.txt
# Chapter 157 ('Latency
# If you have users around the world, you might want to have servers at various
# locations worldwide so that each user can be served from a datacenter that is geo‐
# graphically close to them. That avoids the users having to wait for network pack‐
# ets to travel halfway around the world.') written to ./books/Designing Data Intensive Applications/chapter_157.txt
# Chapter 158 ('ii. Network Attached Storage (NAS) or Storage Area Network (SAN).') written to ./books/Designing Data Intensive Applications/chapter_158.txt
# Chapter 159 ('These are separate mechanisms, but they often go hand in hand, as illustrated in
# Figure II-1.') written to ./books/Designing Data Intensive Applications/chapter_159.txt
# Chapter 160 ('[4] Frank McSherry, Michael Isard, and Derek G. Murray: “Scalability! But at What
# COST?,” at 15th USENIX Workshop on Hot Topics in Operating Systems (HotOS),
# May 2015.') written to ./books/Designing Data Intensive Applications/chapter_160.txt
# Chapter 161 ('151') written to ./books/Designing Data Intensive Applications/chapter_161.txt
# Chapter 162 ('152
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_162.txt
# Chapter 163 ('Leaders and Followers
# |
# 153') written to ./books/Designing Data Intensive Applications/chapter_163.txt
# Chapter 164 ('154
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_164.txt
# Chapter 165 ('Leaders and Followers
# |
# 155') written to ./books/Designing Data Intensive Applications/chapter_165.txt
# Chapter 166 ('156
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_166.txt
# Chapter 167 ('Leaders and Followers
# |
# 157') written to ./books/Designing Data Intensive Applications/chapter_167.txt
# Chapter 168 ('158
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_168.txt
# Chapter 169 ('Leaders and Followers
# |
# 159') written to ./books/Designing Data Intensive Applications/chapter_169.txt
# Chapter 170 ('160
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_170.txt
# Chapter 171 ('Problems with Replication Lag
# |
# 161') written to ./books/Designing Data Intensive Applications/chapter_171.txt
# Chapter 172 ('162
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_172.txt
# Chapter 173 ('Problems with Replication Lag
# |
# 163') written to ./books/Designing Data Intensive Applications/chapter_173.txt
# Chapter 174 ('164
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_174.txt
# Chapter 175 ('Problems with Replication Lag
# |
# 165') written to ./books/Designing Data Intensive Applications/chapter_175.txt
# Chapter 176 ('166
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_176.txt
# Chapter 177 ('Problems with Replication Lag
# |
# 167') written to ./books/Designing Data Intensive Applications/chapter_177.txt
# Chapter 178 ('168
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_178.txt
# Chapter 179 ('Multi-Leader Replication
# |
# 169') written to ./books/Designing Data Intensive Applications/chapter_179.txt
# Chapter 180 ('170
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_180.txt
# Chapter 181 ('Multi-Leader Replication
# |
# 171') written to ./books/Designing Data Intensive Applications/chapter_181.txt
# Chapter 182 ('172
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_182.txt
# Chapter 183 ('Multi-Leader Replication
# |
# 173') written to ./books/Designing Data Intensive Applications/chapter_183.txt
# Chapter 184 ('174
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_184.txt
# Chapter 185 ('Multi-Leader Replication
# |
# 175') written to ./books/Designing Data Intensive Applications/chapter_185.txt
# Chapter 186 ('176
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_186.txt
# Chapter 187 ('Leaderless Replication
# |
# 177') written to ./books/Designing Data Intensive Applications/chapter_187.txt
# Chapter 188 ('178
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_188.txt
# Chapter 189 ('Leaderless Replication
# |
# 179') written to ./books/Designing Data Intensive Applications/chapter_189.txt
# Chapter 190 ('180
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_190.txt
# Chapter 191 ('Leaderless Replication
# |
# 181') written to ./books/Designing Data Intensive Applications/chapter_191.txt
# Chapter 192 ('182
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_192.txt
# Chapter 193 ('Leaderless Replication
# |
# 183') written to ./books/Designing Data Intensive Applications/chapter_193.txt
# Chapter 194 ('184
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_194.txt
# Chapter 195 ('Leaderless Replication
# |
# 185') written to ./books/Designing Data Intensive Applications/chapter_195.txt
# Chapter 196 ('186
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_196.txt
# Chapter 197 ('Leaderless Replication
# |
# 187') written to ./books/Designing Data Intensive Applications/chapter_197.txt
# Chapter 198 ('188
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_198.txt
# Chapter 199 ('Leaderless Replication
# |
# 189') written to ./books/Designing Data Intensive Applications/chapter_199.txt
# Chapter 200 ('190
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_200.txt
# Chapter 201 ('Leaderless Replication
# |
# 191') written to ./books/Designing Data Intensive Applications/chapter_201.txt
# Chapter 202 ('192
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_202.txt
# Chapter 203 ('Summary
# |
# 193') written to ./books/Designing Data Intensive Applications/chapter_203.txt
# Chapter 204 ('194
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_204.txt
# Chapter 205 ('Summary
# |
# 195') written to ./books/Designing Data Intensive Applications/chapter_205.txt
# Chapter 206 ('196
# |
# Chapter 5: Replication') written to ./books/Designing Data Intensive Applications/chapter_206.txt
# Chapter 207 ('Summary
# |
# 197') written to ./books/Designing Data Intensive Applications/chapter_207.txt
# Chapter 208 ('199') written to ./books/Designing Data Intensive Applications/chapter_208.txt
# Chapter 209 ('200
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_209.txt
# Chapter 210 ('Partitioning of Key-Value Data
# |
# 201') written to ./books/Designing Data Intensive Applications/chapter_210.txt
# Chapter 211 ('202
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_211.txt
# Chapter 212 ('Partitioning of Key-Value Data
# |
# 203') written to ./books/Designing Data Intensive Applications/chapter_212.txt
# Chapter 213 ('204
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_213.txt
# Chapter 214 ('Partitioning of Key-Value Data
# |
# 205') written to ./books/Designing Data Intensive Applications/chapter_214.txt
# Chapter 215 ('206
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_215.txt
# Chapter 216 ('Partitioning and Secondary Indexes
# |
# 207') written to ./books/Designing Data Intensive Applications/chapter_216.txt
# Chapter 217 ('208
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_217.txt
# Chapter 218 ('Rebalancing Partitions
# |
# 209') written to ./books/Designing Data Intensive Applications/chapter_218.txt
# Chapter 219 ('210
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_219.txt
# Chapter 220 ('Rebalancing Partitions
# |
# 211') written to ./books/Designing Data Intensive Applications/chapter_220.txt
# Chapter 221 ('212
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_221.txt
# Chapter 222 ('Rebalancing Partitions
# |
# 213') written to ./books/Designing Data Intensive Applications/chapter_222.txt
# Chapter 223 ('214
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_223.txt
# Chapter 224 ('Request Routing
# |
# 215') written to ./books/Designing Data Intensive Applications/chapter_224.txt
# Chapter 225 ('216
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_225.txt
# Chapter 226 ('Summary
# |
# 217') written to ./books/Designing Data Intensive Applications/chapter_226.txt
# Chapter 227 ('218
# |
# Chapter 6: Partitioning') written to ./books/Designing Data Intensive Applications/chapter_227.txt
# Chapter 228 ('Summary
# |
# 219') written to ./books/Designing Data Intensive Applications/chapter_228.txt
# Chapter 229 ('221') written to ./books/Designing Data Intensive Applications/chapter_229.txt
# Chapter 230 ('222
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_230.txt
# Chapter 231 ('The Slippery Concept of a Transaction
# |
# 223') written to ./books/Designing Data Intensive Applications/chapter_231.txt
# Chapter 232 ('224
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_232.txt
# Chapter 233 ('The Slippery Concept of a Transaction
# |
# 225') written to ./books/Designing Data Intensive Applications/chapter_233.txt
# Chapter 234 ('226
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_234.txt
# Chapter 235 ('The Slippery Concept of a Transaction
# |
# 227') written to ./books/Designing Data Intensive Applications/chapter_235.txt
# Chapter 236 ('228
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_236.txt
# Chapter 237 ('The Slippery Concept of a Transaction
# |
# 229') written to ./books/Designing Data Intensive Applications/chapter_237.txt
# Chapter 238 ('230
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_238.txt
# Chapter 239 ('The Slippery Concept of a Transaction
# |
# 231') written to ./books/Designing Data Intensive Applications/chapter_239.txt
# Chapter 240 ('232
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_240.txt
# Chapter 241 ('Weak Isolation Levels
# |
# 233') written to ./books/Designing Data Intensive Applications/chapter_241.txt
# Chapter 242 ('234
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_242.txt
# Chapter 243 ('Weak Isolation Levels
# |
# 235') written to ./books/Designing Data Intensive Applications/chapter_243.txt
# Chapter 244 ('236
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_244.txt
# Chapter 245 ('Weak Isolation Levels
# |
# 237') written to ./books/Designing Data Intensive Applications/chapter_245.txt
# Chapter 246 ('238
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_246.txt
# Chapter 247 ('Weak Isolation Levels
# |
# 239') written to ./books/Designing Data Intensive Applications/chapter_247.txt
# Chapter 248 ('240
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_248.txt
# Chapter 249 ('Weak Isolation Levels
# |
# 241') written to ./books/Designing Data Intensive Applications/chapter_249.txt
# Chapter 250 ('242
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_250.txt
# Chapter 251 ('Weak Isolation Levels
# |
# 243') written to ./books/Designing Data Intensive Applications/chapter_251.txt
# Chapter 252 ('244
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_252.txt
# Chapter 253 ('Weak Isolation Levels
# |
# 245') written to ./books/Designing Data Intensive Applications/chapter_253.txt
# Chapter 254 ('246
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_254.txt
# Chapter 255 ('Weak Isolation Levels
# |
# 247') written to ./books/Designing Data Intensive Applications/chapter_255.txt
# Chapter 256 ('248
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_256.txt
# Chapter 257 ('Weak Isolation Levels
# |
# 249') written to ./books/Designing Data Intensive Applications/chapter_257.txt
# Chapter 258 ('250
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_258.txt
# Chapter 259 ('Serializability
# |
# 251') written to ./books/Designing Data Intensive Applications/chapter_259.txt
# Chapter 260 ('252
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_260.txt
# Chapter 261 ('Serializability
# |
# 253') written to ./books/Designing Data Intensive Applications/chapter_261.txt
# Chapter 262 ('254
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_262.txt
# Chapter 263 ('Serializability
# |
# 255') written to ./books/Designing Data Intensive Applications/chapter_263.txt
# Chapter 264 ('256
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_264.txt
# Chapter 265 ('Serializability
# |
# 257') written to ./books/Designing Data Intensive Applications/chapter_265.txt
# Chapter 266 ('258
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_266.txt
# Chapter 267 ('Serializability
# |
# 259') written to ./books/Designing Data Intensive Applications/chapter_267.txt
# Chapter 268 ('260
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_268.txt
# Chapter 269 ('Serializability
# |
# 261') written to ./books/Designing Data Intensive Applications/chapter_269.txt
# Chapter 270 ('262
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_270.txt
# Chapter 271 ('Serializability
# |
# 263') written to ./books/Designing Data Intensive Applications/chapter_271.txt
# Chapter 272 ('264
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_272.txt
# Chapter 273 ('Serializability
# |
# 265') written to ./books/Designing Data Intensive Applications/chapter_273.txt
# Chapter 274 ('266
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_274.txt
# Chapter 275 ('Summary
# |
# 267') written to ./books/Designing Data Intensive Applications/chapter_275.txt
# Chapter 276 ('268
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_276.txt
# Chapter 277 ('Summary
# |
# 269') written to ./books/Designing Data Intensive Applications/chapter_277.txt
# Chapter 278 ('270
# |
# Chapter 7: Transactions') written to ./books/Designing Data Intensive Applications/chapter_278.txt
# Chapter 279 ('Summary
# |
# 271') written to ./books/Designing Data Intensive Applications/chapter_279.txt
# Chapter 280 ('273') written to ./books/Designing Data Intensive Applications/chapter_280.txt
# Chapter 281 ('274
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_281.txt
# Chapter 282 ('Faults and Partial Failures
# |
# 275') written to ./books/Designing Data Intensive Applications/chapter_282.txt
# Chapter 283 ('276
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_283.txt
# Chapter 284 ('Unreliable Networks
# |
# 277') written to ./books/Designing Data Intensive Applications/chapter_284.txt
# Chapter 285 ('278
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_285.txt
# Chapter 286 ('Unreliable Networks
# |
# 279') written to ./books/Designing Data Intensive Applications/chapter_286.txt
# Chapter 287 ('280
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_287.txt
# Chapter 288 ('Unreliable Networks
# |
# 281') written to ./books/Designing Data Intensive Applications/chapter_288.txt
# Chapter 289 ('282
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_289.txt
# Chapter 290 ('Unreliable Networks
# |
# 283') written to ./books/Designing Data Intensive Applications/chapter_290.txt
# Chapter 291 ('284
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_291.txt
# Chapter 292 ('Unreliable Networks
# |
# 285') written to ./books/Designing Data Intensive Applications/chapter_292.txt
# Chapter 293 ('286
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_293.txt
# Chapter 294 ('Unreliable Clocks
# |
# 287') written to ./books/Designing Data Intensive Applications/chapter_294.txt
# Chapter 295 ('288
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_295.txt
# Chapter 296 ('Unreliable Clocks
# |
# 289') written to ./books/Designing Data Intensive Applications/chapter_296.txt
# Chapter 297 ('290
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_297.txt
# Chapter 298 ('Unreliable Clocks
# |
# 291') written to ./books/Designing Data Intensive Applications/chapter_298.txt
# Chapter 299 ('292
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_299.txt
# Chapter 300 ('Unreliable Clocks
# |
# 293') written to ./books/Designing Data Intensive Applications/chapter_300.txt
# Chapter 301 ('294
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_301.txt
# Chapter 302 ('Unreliable Clocks
# |
# 295') written to ./books/Designing Data Intensive Applications/chapter_302.txt
# Chapter 303 ('296
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_303.txt
# Chapter 304 ('Unreliable Clocks
# |
# 297') written to ./books/Designing Data Intensive Applications/chapter_304.txt
# Chapter 305 ('298
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_305.txt
# Chapter 306 ('Unreliable Clocks
# |
# 299') written to ./books/Designing Data Intensive Applications/chapter_306.txt
# Chapter 307 ('300
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_307.txt
# Chapter 308 ('Knowledge, Truth, and Lies
# |
# 301') written to ./books/Designing Data Intensive Applications/chapter_308.txt
# Chapter 309 ('302
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_309.txt
# Chapter 310 ('Knowledge, Truth, and Lies
# |
# 303') written to ./books/Designing Data Intensive Applications/chapter_310.txt
# Chapter 311 ('304
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_311.txt
# Chapter 312 ('Knowledge, Truth, and Lies
# |
# 305') written to ./books/Designing Data Intensive Applications/chapter_312.txt
# Chapter 313 ('306
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_313.txt
# Chapter 314 ('Knowledge, Truth, and Lies
# |
# 307') written to ./books/Designing Data Intensive Applications/chapter_314.txt
# Chapter 315 ('308
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_315.txt
# Chapter 316 ('Knowledge, Truth, and Lies
# |
# 309') written to ./books/Designing Data Intensive Applications/chapter_316.txt
# Chapter 317 ('310
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_317.txt
# Chapter 318 ('Summary
# |
# 311') written to ./books/Designing Data Intensive Applications/chapter_318.txt
# Chapter 319 ('312
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_319.txt
# Chapter 320 ('Summary
# |
# 313') written to ./books/Designing Data Intensive Applications/chapter_320.txt
# Chapter 321 ('314
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_321.txt
# Chapter 322 ('Summary
# |
# 315') written to ./books/Designing Data Intensive Applications/chapter_322.txt
# Chapter 323 ('316
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_323.txt
# Chapter 324 ('Summary
# |
# 317') written to ./books/Designing Data Intensive Applications/chapter_324.txt
# Chapter 325 ('318
# |
# Chapter 8: The Trouble with Distributed Systems') written to ./books/Designing Data Intensive Applications/chapter_325.txt
# Chapter 326 ('321') written to ./books/Designing Data Intensive Applications/chapter_326.txt
# Chapter 327 ('322
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_327.txt
# Chapter 328 ('Consistency Guarantees
# |
# 323') written to ./books/Designing Data Intensive Applications/chapter_328.txt
# Chapter 329 ('324
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_329.txt
# Chapter 330 ('Linearizability
# |
# 325') written to ./books/Designing Data Intensive Applications/chapter_330.txt
# Chapter 331 ('326
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_331.txt
# Chapter 332 ('Linearizability
# |
# 327') written to ./books/Designing Data Intensive Applications/chapter_332.txt
# Chapter 333 ('328
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_333.txt
# Chapter 334 ('Linearizability
# |
# 329') written to ./books/Designing Data Intensive Applications/chapter_334.txt
# Chapter 335 ('330
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_335.txt
# Chapter 336 ('Linearizability
# |
# 331') written to ./books/Designing Data Intensive Applications/chapter_336.txt
# Chapter 337 ('332
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_337.txt
# Chapter 338 ('Linearizability
# |
# 333') written to ./books/Designing Data Intensive Applications/chapter_338.txt
# Chapter 339 ('334
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_339.txt
# Chapter 340 ('Linearizability
# |
# 335') written to ./books/Designing Data Intensive Applications/chapter_340.txt
# Chapter 341 ('336
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_341.txt
# Chapter 342 ('Linearizability
# |
# 337') written to ./books/Designing Data Intensive Applications/chapter_342.txt
# Chapter 343 ('338
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_343.txt
# Chapter 344 ('Ordering Guarantees
# |
# 339') written to ./books/Designing Data Intensive Applications/chapter_344.txt
# Chapter 345 ('340
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_345.txt
# Chapter 346 ('Ordering Guarantees
# |
# 341') written to ./books/Designing Data Intensive Applications/chapter_346.txt
# Chapter 347 ('342
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_347.txt
# Chapter 348 ('Ordering Guarantees
# |
# 343') written to ./books/Designing Data Intensive Applications/chapter_348.txt
# Chapter 349 ('344
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_349.txt
# Chapter 350 ('Ordering Guarantees
# |
# 345') written to ./books/Designing Data Intensive Applications/chapter_350.txt
# Chapter 351 ('346
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_351.txt
# Chapter 352 ('Ordering Guarantees
# |
# 347') written to ./books/Designing Data Intensive Applications/chapter_352.txt
# Chapter 353 ('348
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_353.txt
# Chapter 354 ('Ordering Guarantees
# |
# 349') written to ./books/Designing Data Intensive Applications/chapter_354.txt
# Chapter 355 ('350
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_355.txt
# Chapter 356 ('Ordering Guarantees
# |
# 351') written to ./books/Designing Data Intensive Applications/chapter_356.txt
# Chapter 357 ('352
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_357.txt
# Chapter 358 ('Distributed Transactions and Consensus
# |
# 353') written to ./books/Designing Data Intensive Applications/chapter_358.txt
# Chapter 359 ('354
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_359.txt
# Chapter 360 ('Distributed Transactions and Consensus
# |
# 355') written to ./books/Designing Data Intensive Applications/chapter_360.txt
# Chapter 361 ('356
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_361.txt
# Chapter 362 ('Distributed Transactions and Consensus
# |
# 357') written to ./books/Designing Data Intensive Applications/chapter_362.txt
# Chapter 363 ('358
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_363.txt
# Chapter 364 ('Distributed Transactions and Consensus
# |
# 359') written to ./books/Designing Data Intensive Applications/chapter_364.txt
# Chapter 365 ('360
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_365.txt
# Chapter 366 ('Distributed Transactions and Consensus
# |
# 361') written to ./books/Designing Data Intensive Applications/chapter_366.txt
# Chapter 367 ('362
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_367.txt
# Chapter 368 ('Distributed Transactions and Consensus
# |
# 363') written to ./books/Designing Data Intensive Applications/chapter_368.txt
# Chapter 369 ('364
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_369.txt
# Chapter 370 ('Distributed Transactions and Consensus
# |
# 365') written to ./books/Designing Data Intensive Applications/chapter_370.txt
# Chapter 371 ('366
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_371.txt
# Chapter 372 ('Distributed Transactions and Consensus
# |
# 367') written to ./books/Designing Data Intensive Applications/chapter_372.txt
# Chapter 373 ('368
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_373.txt
# Chapter 374 ('Distributed Transactions and Consensus
# |
# 369') written to ./books/Designing Data Intensive Applications/chapter_374.txt
# Chapter 375 ('370
# |
# Chapter 9: Consistency and Consensus') written to ./books/Designing Data Intensive Applications/chapter_375.txt
# Chapter 376 ('Distributed Transactions and Consensus
# |
# 371') written to ./books/Designing Data Intensive Applications/chapter_376.txt
# Chapter 377 ('372
# |
# ...
# Chapter 459 ('458
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_459.txt
# Chapter 460 ('Databases and Streams
# |
# 459') written to ./books/Designing Data Intensive Applications/chapter_460.txt
# Chapter 461 ('460
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_461.txt
# Chapter 462 ('Databases and Streams
# |
# 461') written to ./books/Designing Data Intensive Applications/chapter_462.txt
# Chapter 463 ('462
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_463.txt
# Chapter 464 ('Databases and Streams
# |
# 463') written to ./books/Designing Data Intensive Applications/chapter_464.txt
# Chapter 465 ('464
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_465.txt
# Chapter 466 ('Processing Streams
# |
# 465') written to ./books/Designing Data Intensive Applications/chapter_466.txt
# Chapter 467 ('466
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_467.txt
# Chapter 468 ('Processing Streams
# |
# 467') written to ./books/Designing Data Intensive Applications/chapter_468.txt
# Chapter 469 ('468
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_469.txt
# Chapter 470 ('Processing Streams
# |
# 469') written to ./books/Designing Data Intensive Applications/chapter_470.txt
# Chapter 471 ('470
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_471.txt
# Chapter 472 ('Processing Streams
# |
# 471') written to ./books/Designing Data Intensive Applications/chapter_472.txt
# Chapter 473 ('472
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_473.txt
# Chapter 474 ('Processing Streams
# |
# 473') written to ./books/Designing Data Intensive Applications/chapter_474.txt
# Chapter 475 ('474
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_475.txt
# Chapter 476 ('Processing Streams
# |
# 475') written to ./books/Designing Data Intensive Applications/chapter_476.txt
# Chapter 477 ('476
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_477.txt
# Chapter 478 ('Processing Streams
# |
# 477') written to ./books/Designing Data Intensive Applications/chapter_478.txt
# Chapter 479 ('478
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_479.txt
# Chapter 480 ('Summary
# |
# 479') written to ./books/Designing Data Intensive Applications/chapter_480.txt
# Chapter 481 ('480
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_481.txt
# Chapter 482 ('Summary
# |
# 481') written to ./books/Designing Data Intensive Applications/chapter_482.txt
# Chapter 483 ('482
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_483.txt
# Chapter 484 ('Summary
# |
# 483') written to ./books/Designing Data Intensive Applications/chapter_484.txt
# Chapter 485 ('484
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_485.txt
# Chapter 486 ('Summary
# |
# 485') written to ./books/Designing Data Intensive Applications/chapter_486.txt
# Chapter 487 ('486
# |
# Chapter 11: Stream Processing') written to ./books/Designing Data Intensive Applications/chapter_487.txt
# Chapter 488 ('Summary
# |
# 487') written to ./books/Designing Data Intensive Applications/chapter_488.txt
# Chapter 489 ('489') written to ./books/Designing Data Intensive Applications/chapter_489.txt
# Chapter 490 ('490
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_490.txt
# Chapter 491 ('Data Integration
# |
# 491') written to ./books/Designing Data Intensive Applications/chapter_491.txt
# Chapter 492 ('492
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_492.txt
# Chapter 493 ('Data Integration
# |
# 493') written to ./books/Designing Data Intensive Applications/chapter_493.txt
# Chapter 494 ('494
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_494.txt
# Chapter 495 ('Data Integration
# |
# 495') written to ./books/Designing Data Intensive Applications/chapter_495.txt
# Chapter 496 ('496
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_496.txt
# Chapter 497 ('Data Integration
# |
# 497') written to ./books/Designing Data Intensive Applications/chapter_497.txt
# Chapter 498 ('498
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_498.txt
# Chapter 499 ('Unbundling Databases
# |
# 499') written to ./books/Designing Data Intensive Applications/chapter_499.txt
# Chapter 500 ('500
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_500.txt
# Chapter 501 ('Unbundling Databases
# |
# 501') written to ./books/Designing Data Intensive Applications/chapter_501.txt
# Chapter 502 ('502
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_502.txt
# Chapter 503 ('Unbundling Databases
# |
# 503') written to ./books/Designing Data Intensive Applications/chapter_503.txt
# Chapter 504 ('504
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_504.txt
# Chapter 505 ('Unbundling Databases
# |
# 505') written to ./books/Designing Data Intensive Applications/chapter_505.txt
# Chapter 506 ('506
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_506.txt
# Chapter 507 ('Unbundling Databases
# |
# 507') written to ./books/Designing Data Intensive Applications/chapter_507.txt
# Chapter 508 ('508
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_508.txt
# Chapter 509 ('Unbundling Databases
# |
# 509') written to ./books/Designing Data Intensive Applications/chapter_509.txt
# Chapter 510 ('510
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_510.txt
# Chapter 511 ('Unbundling Databases
# |
# 511') written to ./books/Designing Data Intensive Applications/chapter_511.txt
# Chapter 512 ('512
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_512.txt
# Chapter 513 ('Unbundling Databases
# |
# 513') written to ./books/Designing Data Intensive Applications/chapter_513.txt
# Chapter 514 ('514
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_514.txt
# Chapter 515 ('Aiming for Correctness
# |
# 515') written to ./books/Designing Data Intensive Applications/chapter_515.txt
# Chapter 516 ('516
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_516.txt
# Chapter 517 ('Aiming for Correctness
# |
# 517') written to ./books/Designing Data Intensive Applications/chapter_517.txt
# Chapter 518 ('518
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_518.txt
# Chapter 519 ('Aiming for Correctness
# |
# 519') written to ./books/Designing Data Intensive Applications/chapter_519.txt
# Chapter 520 ('520
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_520.txt
# Chapter 521 ('Aiming for Correctness
# |
# 521') written to ./books/Designing Data Intensive Applications/chapter_521.txt
# Chapter 522 ('522
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_522.txt
# Chapter 523 ('Aiming for Correctness
# |
# 523') written to ./books/Designing Data Intensive Applications/chapter_523.txt
# Chapter 524 ('524
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_524.txt
# Chapter 525 ('Aiming for Correctness
# |
# 525') written to ./books/Designing Data Intensive Applications/chapter_525.txt
# Chapter 526 ('526
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_526.txt
# Chapter 527 ('Aiming for Correctness
# |
# 527') written to ./books/Designing Data Intensive Applications/chapter_527.txt
# Chapter 528 ('528
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_528.txt
# Chapter 529 ('Aiming for Correctness
# |
# 529') written to ./books/Designing Data Intensive Applications/chapter_529.txt
# Chapter 530 ('530
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_530.txt
# Chapter 531 ('Aiming for Correctness
# |
# 531') written to ./books/Designing Data Intensive Applications/chapter_531.txt
# Chapter 532 ('532
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_532.txt
# Chapter 533 ('Doing the Right Thing
# |
# 533') written to ./books/Designing Data Intensive Applications/chapter_533.txt
# Chapter 534 ('534
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_534.txt
# Chapter 535 ('Doing the Right Thing
# |
# 535') written to ./books/Designing Data Intensive Applications/chapter_535.txt
# Chapter 536 ('536
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_536.txt
# Chapter 537 ('Doing the Right Thing
# |
# 537') written to ./books/Designing Data Intensive Applications/chapter_537.txt
# Chapter 538 ('538
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_538.txt
# Chapter 539 ('Doing the Right Thing
# |
# 539') written to ./books/Designing Data Intensive Applications/chapter_539.txt
# Chapter 540 ('540
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_540.txt
# Chapter 541 ('Doing the Right Thing
# |
# 541') written to ./books/Designing Data Intensive Applications/chapter_541.txt
# Chapter 542 ('542
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_542.txt
# Chapter 543 ('Summary
# |
# 543') written to ./books/Designing Data Intensive Applications/chapter_543.txt
# Chapter 544 ('544
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_544.txt
# Chapter 545 ('Summary
# |
# 545') written to ./books/Designing Data Intensive Applications/chapter_545.txt
# Chapter 546 ('546
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_546.txt
# Chapter 547 ('Summary
# |
# 547') written to ./books/Designing Data Intensive Applications/chapter_547.txt
# Chapter 548 ('548
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_548.txt
# Chapter 549 ('Summary
# |
# 549') written to ./books/Designing Data Intensive Applications/chapter_549.txt
# Chapter 550 ('550
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_550.txt
# Chapter 551 ('Summary
# |
# 551') written to ./books/Designing Data Intensive Applications/chapter_551.txt
# Chapter 552 ('552
# |
# Chapter 12: The Future of Data Systems') written to ./books/Designing Data Intensive Applications/chapter_552.txt
# Chapter 553 ('Glossary
# |
# 553') written to ./books/Designing Data Intensive Applications/chapter_553.txt
# Chapter 554 ('554
# |
# Glossary') written to ./books/Designing Data Intensive Applications/chapter_554.txt
# Chapter 555 ('Glossary
# |
# 555') written to ./books/Designing Data Intensive Applications/chapter_555.txt
# Chapter 556 ('556
# |
# Glossary') written to ./books/Designing Data Intensive Applications/chapter_556.txt
# Chapter 557 ('Glossary
# |
# 557') written to ./books/Designing Data Intensive Applications/chapter_557.txt
# Chapter 558 ('558
# |
# Glossary') written to ./books/Designing Data Intensive Applications/chapter_558.txt
# Chapter 559 ('Index
# |
# 559') written to ./books/Designing Data Intensive Applications/chapter_559.txt
# Chapter 560 ('560
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_560.txt
# Chapter 561 ('Index
# |
# 561') written to ./books/Designing Data Intensive Applications/chapter_561.txt
# Chapter 562 ('562
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_562.txt
# Chapter 563 ('Index
# |
# 563') written to ./books/Designing Data Intensive Applications/chapter_563.txt
# Chapter 564 ('564
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_564.txt
# Chapter 565 ('Index
# |
# 565') written to ./books/Designing Data Intensive Applications/chapter_565.txt
# Chapter 566 ('566
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_566.txt
# Chapter 567 ('Index
# |
# 567') written to ./books/Designing Data Intensive Applications/chapter_567.txt
# Chapter 568 ('568
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_568.txt
# Chapter 569 ('Index
# |
# 569') written to ./books/Designing Data Intensive Applications/chapter_569.txt
# Chapter 570 ('570
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_570.txt
# Chapter 571 ('Index
# |
# 571') written to ./books/Designing Data Intensive Applications/chapter_571.txt
# Chapter 572 ('572
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_572.txt
# Chapter 573 ('Index
# |
# 573') written to ./books/Designing Data Intensive Applications/chapter_573.txt
# Chapter 574 ('574
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_574.txt
# Chapter 575 ('Index
# |
# 575') written to ./books/Designing Data Intensive Applications/chapter_575.txt
# Chapter 576 ('576
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_576.txt
# Chapter 577 ('Index
# |
# 577') written to ./books/Designing Data Intensive Applications/chapter_577.txt
# Chapter 578 ('578
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_578.txt
# Chapter 579 ('Index
# |
# 579') written to ./books/Designing Data Intensive Applications/chapter_579.txt
# Chapter 580 ('580
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_580.txt
# Chapter 581 ('Index
# |
# 581') written to ./books/Designing Data Intensive Applications/chapter_581.txt
# Chapter 582 ('582
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_582.txt
# Chapter 583 ('Index
# |
# 583') written to ./books/Designing Data Intensive Applications/chapter_583.txt
# Chapter 584 ('584
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_584.txt
# Chapter 585 ('Index
# |
# 585') written to ./books/Designing Data Intensive Applications/chapter_585.txt
# Chapter 586 ('586
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_586.txt
# Chapter 587 ('Index
# |
# 587') written to ./books/Designing Data Intensive Applications/chapter_587.txt
# Chapter 588 ('588
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_588.txt
# Chapter 589 ('Index
# |
# 589') written to ./books/Designing Data Intensive Applications/chapter_589.txt
# Chapter 590 ('590
# |
# Index') written to ./books/Designing Data Intensive Applications/chapter_590.txt
# Chapter 591 ('The cover image is from Shaw’s Zoology. The cover fonts are URW Typewriter and
# Guardian Sans. The text font is Adobe Minion Pro; the font in diagrams is Adobe
# Myriad Pro; the heading font is Adobe Myriad Condensed; and the code font is Dal‐
# ton Maag’s Ubuntu Mono.') written to ./books/Designing Data Intensive Applications/chapter_591.txt

# %%
# version 3 - based on chapter names 

import os
import re
import fitz  # PyMuPDF

# Define a list of patterns to identify chapter names
chapter_patterns = [
    r"^Chapter \d+",         # e.g., "Chapter 1"
    r"^Chapter [A-Za-z]+",   # e.g., "Chapter One"
    r"^Part \d+",            # e.g., "Part 1"
    r"^Section \d+",         # e.g., "Section 1"
    r"^\d+\.\d+",            # e.g., "1.1"
    r"^\d+$",                # e.g., "1" (sometimes used for chapter names)
]

# Function to detect chapter titles based on patterns
def is_chapter_title(text):
    for pattern in chapter_patterns:
        if re.match(pattern, text.strip()):
            return True
    return False

# Function to extract chapters and write them to separate files
def extract_chapters(pdf_path):
    # Open the PDF
    doc = fitz.open(pdf_path)
    
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = f"./books/{book_name}"
    os.makedirs(output_dir, exist_ok=True)

    # Initialize variables
    chapter_indices = []  # Store start page indices of chapters
    chapter_titles = []   # Store chapter titles
    current_chapter = None

    # Iterate over each page and detect chapter names
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        for block in text_blocks:
            block_text = block[4].strip()  # Extract the actual text from the block

            # Check if the block text matches any chapter patterns
            if is_chapter_title(block_text):
                chapter_indices.append(page_num)
                chapter_titles.append(block_text)
                print(f"Chapter detected: '{block_text}' on page {page_num + 1}")
                break  # Stop after detecting the first chapter title on a page

    # If no chapters were found, exit the function
    if not chapter_indices:
        print("No chapters detected. Exiting...")
        return

    # Add a final index to cover the last chapter to the end of the document
    chapter_indices.append(len(doc))

    # Write each chapter to a separate file
    for i in range(len(chapter_indices) - 1):
        start_page = chapter_indices[i]
        end_page = chapter_indices[i + 1]
        chapter_title = chapter_titles[i]

        # Extract text for the current chapter
        chapter_text = ""
        for j in range(start_page, end_page):
            page = doc.load_page(j)
            chapter_text += page.get_text("text")

        # Save the chapter to a separate file
        sanitized_title = re.sub(r'[\\/*?:"<>|]', "", chapter_title)  # Remove invalid filename chars
        chapter_filename = f"{output_dir}/{sanitized_title}_Chapter_{i+1}.txt"
        
        with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
            chapter_file.write(chapter_text)

        print(f"Chapter '{chapter_title}' written to {chapter_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
extract_chapters(pdf_path)
# Out:
# Chapter detected: '3' on page 25
# Chapter detected: '27' on page 49
# Chapter detected: '69' on page 91
# Chapter detected: '111' on page 133
# Chapter detected: '151' on page 173
# Chapter detected: '199' on page 221
# Chapter detected: '221' on page 243
# Chapter detected: '273' on page 295
# Chapter detected: '321' on page 343
# Chapter detected: 'Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another
# attempt to introduce order into a disorderly world, for example to determine
# which one of two writes happened later.' on page 361
# Chapter detected: '389' on page 411
# Chapter detected: '216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"
# 200 3377 "http://martin.kleppmann.com/" "Mozilla/5.0 (Macintosh; Intel Mac OS X
# 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.115
# Safari/537.36"' on page 413
# Chapter detected: '439' on page 461
# Chapter detected: '489' on page 511
# Chapter detected: '232' on page 581
# Chapter detected: '451' on page 582
# Chapter detected: '242' on page 583
# Chapter detected: '295' on page 585
# Chapter detected: '264' on page 586
# Chapter detected: '506' on page 588
# Chapter detected: '153' on page 589
# Chapter detected: '498' on page 590
# Chapter detected: '284' on page 591
# Chapter detected: '295' on page 592
# Chapter detected: '364' on page 593
# Chapter detected: '275' on page 594
# Chapter detected: '284' on page 595
# Chapter detected: '286' on page 596
# Chapter detected: '244' on page 597
# Chapter detected: '521' on page 598
# Chapter detected: '508' on page 599
# Chapter detected: '232' on page 600
# Chapter detected: '173' on page 601
# Chapter detected: '504' on page 602
# Chapter detected: '462' on page 605
# Chapter detected: '508' on page 606
# Chapter detected: '458' on page 607
# Chapter detected: '471' on page 609
# Chapter detected: '294' on page 610
# Chapter detected: '89' on page 611
# Chapter '3' written to ./books/Designing Data Intensive Applications/3_Chapter_1.txt
# Chapter '27' written to ./books/Designing Data Intensive Applications/27_Chapter_2.txt
# Chapter '69' written to ./books/Designing Data Intensive Applications/69_Chapter_3.txt
# Chapter '111' written to ./books/Designing Data Intensive Applications/111_Chapter_4.txt
# Chapter '151' written to ./books/Designing Data Intensive Applications/151_Chapter_5.txt
# Chapter '199' written to ./books/Designing Data Intensive Applications/199_Chapter_6.txt
# Chapter '221' written to ./books/Designing Data Intensive Applications/221_Chapter_7.txt
# Chapter '273' written to ./books/Designing Data Intensive Applications/273_Chapter_8.txt
# Chapter '321' written to ./books/Designing Data Intensive Applications/321_Chapter_9.txt
# Chapter 'Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another
# attempt to introduce order into a disorderly world, for example to determine
# which one of two writes happened later.' written to ./books/Designing Data Intensive Applications/Chapter 8 (see “Relying on Synchronized Clocks” on_Chapter_10.txt
# Chapter '389' written to ./books/Designing Data Intensive Applications/389_Chapter_11.txt
# Chapter '216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"
# 200 3377 "http://martin.kleppmann.com/" "Mozilla/5.0 (Macintosh; Intel Mac OS X
# 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.115
# Safari/537.36"' written to ./books/Designing Data Intensive Applications/216.58.210.78 - - [27Feb2015175511 +0000] GET csst_Chapter_12.txt
# Chapter '439' written to ./books/Designing Data Intensive Applications/439_Chapter_13.txt
# Chapter '489' written to ./books/Designing Data Intensive Applications/489_Chapter_14.txt
# Chapter '232' written to ./books/Designing Data Intensive Applications/232_Chapter_15.txt
# Chapter '451' written to ./books/Designing Data Intensive Applications/451_Chapter_16.txt
# Chapter '242' written to ./books/Designing Data Intensive Applications/242_Chapter_17.txt
# Chapter '295' written to ./books/Designing Data Intensive Applications/295_Chapter_18.txt
# Chapter '264' written to ./books/Designing Data Intensive Applications/264_Chapter_19.txt
# Chapter '506' written to ./books/Designing Data Intensive Applications/506_Chapter_20.txt
# Chapter '153' written to ./books/Designing Data Intensive Applications/153_Chapter_21.txt
# Chapter '498' written to ./books/Designing Data Intensive Applications/498_Chapter_22.txt
# Chapter '284' written to ./books/Designing Data Intensive Applications/284_Chapter_23.txt
# Chapter '295' written to ./books/Designing Data Intensive Applications/295_Chapter_24.txt
# Chapter '364' written to ./books/Designing Data Intensive Applications/364_Chapter_25.txt
# Chapter '275' written to ./books/Designing Data Intensive Applications/275_Chapter_26.txt
# Chapter '284' written to ./books/Designing Data Intensive Applications/284_Chapter_27.txt
# Chapter '286' written to ./books/Designing Data Intensive Applications/286_Chapter_28.txt
# Chapter '244' written to ./books/Designing Data Intensive Applications/244_Chapter_29.txt
# Chapter '521' written to ./books/Designing Data Intensive Applications/521_Chapter_30.txt
# Chapter '508' written to ./books/Designing Data Intensive Applications/508_Chapter_31.txt
# Chapter '232' written to ./books/Designing Data Intensive Applications/232_Chapter_32.txt
# Chapter '173' written to ./books/Designing Data Intensive Applications/173_Chapter_33.txt
# Chapter '504' written to ./books/Designing Data Intensive Applications/504_Chapter_34.txt
# Chapter '462' written to ./books/Designing Data Intensive Applications/462_Chapter_35.txt
# Chapter '508' written to ./books/Designing Data Intensive Applications/508_Chapter_36.txt
# Chapter '458' written to ./books/Designing Data Intensive Applications/458_Chapter_37.txt
# Chapter '471' written to ./books/Designing Data Intensive Applications/471_Chapter_38.txt
# Chapter '294' written to ./books/Designing Data Intensive Applications/294_Chapter_39.txt
# Chapter '89' written to ./books/Designing Data Intensive Applications/89_Chapter_40.txt

# %%
# version 4

import os
import re
import fitz  # PyMuPDF

# Define a list of patterns to identify chapter names
chapter_patterns = [
    r"^Chapter \d+",         # e.g., "Chapter 1"
    r"^Chapter [A-Za-z]+",   # e.g., "Chapter One"
    r"^Part \d+",            # e.g., "Part 1"
    r"^Section \d+",         # e.g., "Section 1"
    r"^\d+\.\d+",            # e.g., "1.1"
    r"^\d+$",                # e.g., "1" (sometimes used for chapter names)
]

# Function to detect chapter titles based on patterns
def is_chapter_title(text):
    for pattern in chapter_patterns:
        if re.match(pattern, text.strip()):
            return True
    return False

# Function to filter chapter candidates by analyzing font size and position
def is_valid_chapter_candidate(block, avg_font_size):
    block_text = block[4].strip()
    font_size = block[3]  # Font size is stored at index 3 in the block tuple
    bbox = block[:4]  # Bounding box of the text block: [x0, y0, x1, y1]
    y_position = bbox[1]  # Top y-coordinate (position on the page)

    # Conditions to consider it a valid chapter title:
    return (
        is_chapter_title(block_text) and
        font_size >= avg_font_size and  # Ensure the font size is larger than the average
        y_position < 200  # Chapter titles are usually positioned at the top
    )

# Function to extract chapters and write them to separate files
def extract_chapters(pdf_path):
    # Open the PDF
    doc = fitz.open(pdf_path)
    
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = f"./books/{book_name}"
    os.makedirs(output_dir, exist_ok=True)

    # Initialize variables
    chapter_indices = []  # Store start page indices of chapters
    chapter_titles = []   # Store chapter titles
    current_chapter = None

    # Iterate over each page and detect chapter names
    font_sizes = []
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        # Gather font size statistics to calculate average
        for block in text_blocks:
            font_sizes.append(block[3])  # Font size is stored at index 3 in the block tuple

    avg_font_size = sum(font_sizes) / len(font_sizes)  # Calculate average font size

    # Re-check each page to identify chapters based on font size and patterns
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        for block in text_blocks:
            if is_valid_chapter_candidate(block, avg_font_size):
                chapter_indices.append(page_num)
                chapter_titles.append(block[4].strip())  # Store the cleaned chapter title
                print(f"Chapter detected: '{block[4].strip()}' on page {page_num + 1}")
                break  # Stop after detecting the first chapter title on a page

    # If no chapters were found, exit the function
    if not chapter_indices:
        print("No chapters detected. Exiting...")
        return

    # Add a final index to cover the last chapter to the end of the document
    chapter_indices.append(len(doc))

    # Write each chapter to a separate file
    for i in range(len(chapter_indices) - 1):
        start_page = chapter_indices[i]
        end_page = chapter_indices[i + 1]
        chapter_title = chapter_titles[i]

        # Extract text for the current chapter
        chapter_text = ""
        for j in range(start_page, end_page):
            page = doc.load_page(j)
            chapter_text += page.get_text("text")

        # Sanitize the chapter title to use as filename
        sanitized_title = re.sub(r'[\\/*?:"<>|]', "", chapter_title)  # Remove invalid filename chars
        chapter_filename = f"{output_dir}/{sanitized_title}_Chapter_{i+1}.txt"
        
        with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
            chapter_file.write(chapter_text)

        print(f"Chapter '{chapter_title}' written to {chapter_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
extract_chapters(pdf_path)
# Out:
# No chapters detected. Exiting...

# %%
# version 5
import os
import re
import fitz  # PyMuPDF

# Define a list of patterns to identify chapter names
chapter_patterns = [
    r"^Chapter \d+",         # e.g., "Chapter 1"
    r"^Chapter [A-Za-z]+",   # e.g., "Chapter One"
    r"^Part \d+",            # e.g., "Part 1"
    r"^Section \d+",         # e.g., "Section 1"
    r"^\d+\.\d+",            # e.g., "1.1"
    r"^\d+$",                # e.g., "1" (sometimes used for chapter names)
]

# Function to detect chapter titles based on patterns
def is_chapter_title(text):
    for pattern in chapter_patterns:
        if re.match(pattern, text.strip()):
            return True
    return False

# Function to extract chapters and write them to separate files
def extract_chapters(pdf_path):
    # Open the PDF
    doc = fitz.open(pdf_path)
    
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = f"./books/{book_name}"
    os.makedirs(output_dir, exist_ok=True)

    # Initialize variables
    chapter_indices = []  # Store start page indices of chapters
    chapter_titles = []   # Store chapter titles

    # Iterate over each page and detect chapter names
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        for block in text_blocks:
            block_text = block[4].strip()  # Extract the actual text from the block

            # Check if the block text matches any chapter patterns
            if is_chapter_title(block_text):
                chapter_indices.append(page_num)
                chapter_titles.append(block_text)
                print(f"Chapter detected: '{block_text}' on page {page_num + 1}")
                break  # Stop after detecting the first chapter title on a page

    # If no chapters were found, exit the function
    if not chapter_indices:
        print("No chapters detected. Exiting...")
        return

    # Add a final index to cover the last chapter to the end of the document
    chapter_indices.append(len(doc))

    # Write each chapter to a separate file
    for i in range(len(chapter_indices) - 1):
        start_page = chapter_indices[i]
        end_page = chapter_indices[i + 1]
        chapter_title = chapter_titles[i]

        # Extract text for the current chapter
        chapter_text = ""
        for j in range(start_page, end_page):
            page = doc.load_page(j)
            chapter_text += page.get_text("text")

        # Sanitize the chapter title to use as filename
        sanitized_title = re.sub(r'[\\/*?:"<>|]', "", chapter_title)  # Remove invalid filename chars
        chapter_filename = f"{output_dir}/{sanitized_title}_Chapter_{i+1}.txt"
        
        with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
            chapter_file.write(chapter_text)

        print(f"Chapter '{chapter_title}' written to {chapter_filename}")

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
extract_chapters(pdf_path)
# Out:
# Chapter detected: '3' on page 25
# Chapter detected: '27' on page 49
# Chapter detected: '69' on page 91
# Chapter detected: '111' on page 133
# Chapter detected: '151' on page 173
# Chapter detected: '199' on page 221
# Chapter detected: '221' on page 243
# Chapter detected: '273' on page 295
# Chapter detected: '321' on page 343
# Chapter detected: 'Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another
# attempt to introduce order into a disorderly world, for example to determine
# which one of two writes happened later.' on page 361
# Chapter detected: '389' on page 411
# Chapter detected: '216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"
# 200 3377 "http://martin.kleppmann.com/" "Mozilla/5.0 (Macintosh; Intel Mac OS X
# 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.115
# Safari/537.36"' on page 413
# Chapter detected: '439' on page 461
# Chapter detected: '489' on page 511
# Chapter detected: '232' on page 581
# Chapter detected: '451' on page 582
# Chapter detected: '242' on page 583
# Chapter detected: '295' on page 585
# Chapter detected: '264' on page 586
# Chapter detected: '506' on page 588
# Chapter detected: '153' on page 589
# Chapter detected: '498' on page 590
# Chapter detected: '284' on page 591
# Chapter detected: '295' on page 592
# Chapter detected: '364' on page 593
# Chapter detected: '275' on page 594
# Chapter detected: '284' on page 595
# Chapter detected: '286' on page 596
# Chapter detected: '244' on page 597
# Chapter detected: '521' on page 598
# Chapter detected: '508' on page 599
# Chapter detected: '232' on page 600
# Chapter detected: '173' on page 601
# Chapter detected: '504' on page 602
# Chapter detected: '462' on page 605
# Chapter detected: '508' on page 606
# Chapter detected: '458' on page 607
# Chapter detected: '471' on page 609
# Chapter detected: '294' on page 610
# Chapter detected: '89' on page 611
# Chapter '3' written to ./books/Designing Data Intensive Applications/3_Chapter_1.txt
# Chapter '27' written to ./books/Designing Data Intensive Applications/27_Chapter_2.txt
# Chapter '69' written to ./books/Designing Data Intensive Applications/69_Chapter_3.txt
# Chapter '111' written to ./books/Designing Data Intensive Applications/111_Chapter_4.txt
# Chapter '151' written to ./books/Designing Data Intensive Applications/151_Chapter_5.txt
# Chapter '199' written to ./books/Designing Data Intensive Applications/199_Chapter_6.txt
# Chapter '221' written to ./books/Designing Data Intensive Applications/221_Chapter_7.txt
# Chapter '273' written to ./books/Designing Data Intensive Applications/273_Chapter_8.txt
# Chapter '321' written to ./books/Designing Data Intensive Applications/321_Chapter_9.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 83
#      81 # Example usage
#      82 pdf_path = "Designing Data Intensive Applications.pdf"
# ---> 83 extract_chapters(pdf_path)
#
# Cell In[11], line 76, in extract_chapters(pdf_path)
#      73 sanitized_title = re.sub(r'[\\/*?:"<>|]', "", chapter_title)  # Remove invalid filename chars
#      74 chapter_filename = f"{output_dir}/{sanitized_title}_Chapter_{i+1}.txt"
# ---> 76 with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
#      77     chapter_file.write(chapter_text)
#      79 print(f"Chapter '{chapter_title}' written to {chapter_filename}")
#
# File c:\Users\soric\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './books/Designing Data Intensive Applications/Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another\nattempt to introduce order into a disorderly world, for example to determine\nwhich one of two writes happened later._Chapter_10.txt'

# %%
import os
import re
import fitz  # PyMuPDF

# Define a list of patterns to identify chapter names
chapter_patterns = [
    r"^Chapter \d+",         # e.g., "Chapter 1"
    r"^Chapter [A-Za-z]+",   # e.g., "Chapter One"
    r"^Part \d+",            # e.g., "Part 1"
    r"^Section \d+",         # e.g., "Section 1"
    r"^\d+\.\d+",            # e.g., "1.1"
    r"^\d+$",                # e.g., "1" (sometimes used for chapter names)
]

# Function to detect chapter titles based on patterns
def is_chapter_title(text):
    for pattern in chapter_patterns:
        if re.match(pattern, text.strip()):
            return True
    return False

# Function to sanitize and simplify chapter titles for filenames
def simplify_chapter_title(title, chapter_num):
    # Remove invalid filename characters
    sanitized_title = re.sub(r'[\\/*?:"<>|]', "", title)
    
    # Remove excessive details in parentheses or square brackets
    sanitized_title = re.sub(r'\(.*?\)|\[.*?\]', "", sanitized_title).strip()
    
    # Limit length to 50 characters for filename safety
    if len(sanitized_title) > 50:
        sanitized_title = sanitized_title[:50] + "..."
    
    # If the title is empty after sanitization, use a fallback title
    if not sanitized_title:
        return f"Chapter_{chapter_num}"
    
    return sanitized_title

# Function to extract chapters and write them to separate files
def extract_chapters(pdf_path):
    # Open the PDF
    doc = fitz.open(pdf_path)
    
    # Get the book name and create output directory
    book_name = os.path.splitext(os.path.basename(pdf_path))[0]
    output_dir = f"./books/{book_name}"
    os.makedirs(output_dir, exist_ok=True)

    # Initialize variables
    chapter_indices = []  # Store start page indices of chapters
    chapter_titles = []   # Store chapter titles

    # Iterate over each page and detect chapter names
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text_blocks = page.get_text("blocks")

        for block in text_blocks:
            block_text = block[4].strip()  # Extract the actual text from the block

            # Check if the block text matches any chapter patterns
            if is_chapter_title(block_text):
                chapter_indices.append(page_num)
                chapter_titles.append(block_text)
                print(f"Chapter detected: '{block_text}' on page {page_num + 1}")
                break  # Stop after detecting the first chapter title on a page

    # If no chapters were found, exit the function
    if not chapter_indices:
        print("No chapters detected. Exiting...")
        return

    # Add a final index to cover the last chapter to the end of the document
    chapter_indices.append(len(doc))

    # Write each chapter to a separate file
    for i in range(len(chapter_indices) - 1):
        start_page = chapter_indices[i]
        end_page = chapter_indices[i + 1]
        chapter_title = chapter_titles[i]

        # Extract text for the current chapter
        chapter_text = ""
        for j in range(start_page, end_page):
            page = doc.load_page(j)
            chapter_text += page.get_text("text")

        # Skip chapters that are too short to be valid (less than 100 characters)
        if len(chapter_text) < 100:
            print(f"Skipping short chapter: '{chapter_title}'")
            continue

        # Generate a safe filename for the chapter
        sanitized_title = simplify_chapter_title(chapter_title, i+1)
        chapter_filename = f"{output_dir}/{sanitized_title}_Chapter_{i+1}.txt"
        
        # Write the chapter content to the file
        try:
            with open(chapter_filename, "w", encoding="utf-8") as chapter_file:
                chapter_file.write(chapter_text)
            print(f"Chapter '{chapter_title}' written to {chapter_filename}")
        except Exception as e:
            print(f"Error writing chapter '{chapter_title}': {e}")
            continue

# Example usage
pdf_path = "Designing Data Intensive Applications.pdf"
extract_chapters(pdf_path)
# Out:
# Chapter detected: '3' on page 25
# Chapter detected: '27' on page 49
# Chapter detected: '69' on page 91
# Chapter detected: '111' on page 133
# Chapter detected: '151' on page 173
# Chapter detected: '199' on page 221
# Chapter detected: '221' on page 243
# Chapter detected: '273' on page 295
# Chapter detected: '321' on page 343
# Chapter detected: 'Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another
# attempt to introduce order into a disorderly world, for example to determine
# which one of two writes happened later.' on page 361
# Chapter detected: '389' on page 411
# Chapter detected: '216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"
# 200 3377 "http://martin.kleppmann.com/" "Mozilla/5.0 (Macintosh; Intel Mac OS X
# 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.115
# Safari/537.36"' on page 413
# Chapter detected: '439' on page 461
# Chapter detected: '489' on page 511
# Chapter detected: '232' on page 581
# Chapter detected: '451' on page 582
# Chapter detected: '242' on page 583
# Chapter detected: '295' on page 585
# Chapter detected: '264' on page 586
# Chapter detected: '506' on page 588
# Chapter detected: '153' on page 589
# Chapter detected: '498' on page 590
# Chapter detected: '284' on page 591
# Chapter detected: '295' on page 592
# Chapter detected: '364' on page 593
# Chapter detected: '275' on page 594
# Chapter detected: '284' on page 595
# Chapter detected: '286' on page 596
# Chapter detected: '244' on page 597
# Chapter detected: '521' on page 598
# Chapter detected: '508' on page 599
# Chapter detected: '232' on page 600
# Chapter detected: '173' on page 601
# Chapter detected: '504' on page 602
# Chapter detected: '462' on page 605
# Chapter detected: '508' on page 606
# Chapter detected: '458' on page 607
# Chapter detected: '471' on page 609
# Chapter detected: '294' on page 610
# Chapter detected: '89' on page 611
# Chapter '3' written to ./books/Designing Data Intensive Applications/3_Chapter_1.txt
# Chapter '27' written to ./books/Designing Data Intensive Applications/27_Chapter_2.txt
# Chapter '69' written to ./books/Designing Data Intensive Applications/69_Chapter_3.txt
# Chapter '111' written to ./books/Designing Data Intensive Applications/111_Chapter_4.txt
# Chapter '151' written to ./books/Designing Data Intensive Applications/151_Chapter_5.txt
# Chapter '199' written to ./books/Designing Data Intensive Applications/199_Chapter_6.txt
# Chapter '221' written to ./books/Designing Data Intensive Applications/221_Chapter_7.txt
# Chapter '273' written to ./books/Designing Data Intensive Applications/273_Chapter_8.txt
# Chapter '321' written to ./books/Designing Data Intensive Applications/321_Chapter_9.txt
# Error writing chapter 'Chapter 8 (see “Relying on Synchronized Clocks” on page 291) is another
# attempt to introduce order into a disorderly world, for example to determine
# which one of two writes happened later.': [Errno 22] Invalid argument: './books/Designing Data Intensive Applications/Chapter 8  is another\nattempt to introduce order i..._Chapter_10.txt'
# Chapter '389' written to ./books/Designing Data Intensive Applications/389_Chapter_11.txt
# Error writing chapter '216.58.210.78 - - [27/Feb/2015:17:55:11 +0000] "GET /css/typography.css HTTP/1.1"
# 200 3377 "http://martin.kleppmann.com/" "Mozilla/5.0 (Macintosh; Intel Mac OS X
# 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.115
# Safari/537.36"': [Errno 22] Invalid argument: './books/Designing Data Intensive Applications/216.58.210.78 - -  GET csstypography.css HTTP1.1\n2..._Chapter_12.txt'
# Chapter '439' written to ./books/Designing Data Intensive Applications/439_Chapter_13.txt
# Chapter '489' written to ./books/Designing Data Intensive Applications/489_Chapter_14.txt
# Chapter '232' written to ./books/Designing Data Intensive Applications/232_Chapter_15.txt
# Chapter '451' written to ./books/Designing Data Intensive Applications/451_Chapter_16.txt
# Chapter '242' written to ./books/Designing Data Intensive Applications/242_Chapter_17.txt
# Chapter '295' written to ./books/Designing Data Intensive Applications/295_Chapter_18.txt
# Chapter '264' written to ./books/Designing Data Intensive Applications/264_Chapter_19.txt
# Chapter '506' written to ./books/Designing Data Intensive Applications/506_Chapter_20.txt
# Chapter '153' written to ./books/Designing Data Intensive Applications/153_Chapter_21.txt
# Chapter '498' written to ./books/Designing Data Intensive Applications/498_Chapter_22.txt
# Chapter '284' written to ./books/Designing Data Intensive Applications/284_Chapter_23.txt
# Chapter '295' written to ./books/Designing Data Intensive Applications/295_Chapter_24.txt
# Chapter '364' written to ./books/Designing Data Intensive Applications/364_Chapter_25.txt
# Chapter '275' written to ./books/Designing Data Intensive Applications/275_Chapter_26.txt
# Chapter '284' written to ./books/Designing Data Intensive Applications/284_Chapter_27.txt
# Chapter '286' written to ./books/Designing Data Intensive Applications/286_Chapter_28.txt
# Chapter '244' written to ./books/Designing Data Intensive Applications/244_Chapter_29.txt
# Chapter '521' written to ./books/Designing Data Intensive Applications/521_Chapter_30.txt
# Chapter '508' written to ./books/Designing Data Intensive Applications/508_Chapter_31.txt
# Chapter '232' written to ./books/Designing Data Intensive Applications/232_Chapter_32.txt
# Chapter '173' written to ./books/Designing Data Intensive Applications/173_Chapter_33.txt
# Chapter '504' written to ./books/Designing Data Intensive Applications/504_Chapter_34.txt
# Chapter '462' written to ./books/Designing Data Intensive Applications/462_Chapter_35.txt
# Chapter '508' written to ./books/Designing Data Intensive Applications/508_Chapter_36.txt
# Chapter '458' written to ./books/Designing Data Intensive Applications/458_Chapter_37.txt
# Chapter '471' written to ./books/Designing Data Intensive Applications/471_Chapter_38.txt
# Chapter '294' written to ./books/Designing Data Intensive Applications/294_Chapter_39.txt
# Chapter '89' written to ./books/Designing Data Intensive Applications/89_Chapter_40.txt

# %%
# Install required packages
# !pip install PyPDF2

# Import necessary libraries
import PyPDF2
import json
import os

# Prompt user for the PDF name and book name
pdf_name = input("Enter the name of the PDF file (with extension, e.g., book.pdf): ")
book_name = input("Enter the book name to create a directory under 'books/': ")

# Define paths
output_directory = f"books/{book_name}"
json_output_file = os.path.join(output_directory, f"{book_name}_metadata.json")

# Create the directory if it does not exist
os.makedirs(output_directory, exist_ok=True)

# Initialize an empty structure to hold PDF metadata and outline
pdf_metadata = {
    "file_name": pdf_name,
    "metadata": {},
    "outline": []
}

try:
    # Open the PDF file
    with open(pdf_name, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        
        # Extract document information (metadata)
        pdf_metadata["metadata"] = reader.metadata
        
        # Extract outline (if available)
        if reader.outline:
            def parse_outline(outlines, depth=0):
                outline_structure = []
                for outline in outlines:
                    if isinstance(outline, list):
                        outline_structure.append(parse_outline(outline, depth + 1))
                    else:
                        # Capture title and the destination (page number)
                        outline_structure.append({
                            "title": outline.title,
                            "page": reader.get_destination_page_number(outline)
                        })
                return outline_structure

            pdf_metadata["outline"] = parse_outline(reader.outline)

        # Write metadata to a JSON file
        with open(json_output_file, 'w') as json_file:
            json.dump(pdf_metadata, json_file, indent=4)

        print(f"Metadata extracted and saved to {json_output_file}")

except FileNotFoundError:
    print(f"File '{pdf_name}' not found. Please check the file path and name.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\soric\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# Metadata extracted and saved to books/Designing Data Intensive Applications\Designing Data Intensive Applications_metadata.json

# %%
Designing Data Intensive Applications.pdf

# %%
# Install required packages
# !pip install PyPDF2

# Import necessary libraries
import PyPDF2
import os
import re

# Prompt user for the PDF name
pdf_name = input("Enter the name of the PDF file (with extension, e.g., book.pdf): ")

# Define the book name based on the PDF file name (without extension)
book_name = os.path.splitext(os.path.basename(pdf_name))[0]

# Define the output directory for the extracted chapters
output_directory = f"books/{book_name}"
os.makedirs(output_directory, exist_ok=True)

try:
    # Open the PDF file
    with open(pdf_name, 'rb') as file:
        reader = PyPDF2.PdfReader(file)

        # Extract outline (if available)
        outline = reader.outline

        # Helper function to extract text by page range
        def extract_text(start_page, end_page):
            """Extracts text from start_page to end_page (exclusive)."""
            text = ""
            for page_num in range(start_page, end_page):
                page = reader.pages[page_num]
                text += page.extract_text() or ""  # Handle cases where extract_text returns None
            return text

        # Helper function to clean up the text
        def clean_text(text):
            """Removes page numbers, footers, references, and common unwanted patterns."""
            # Define a pattern for footers with page numbers and chapter titles (e.g., "14 | Chapter 1: Title")
            footer_pattern_1 = re.compile(r'^\s*\d+\s*\|\s*Chapter \d+:.*$', re.MULTILINE)

            # Define a pattern for footers like "Scalability | 13"
            footer_pattern_2 = re.compile(r'^\s*[a-zA-Z\s]+\s*\|\s*\d+\s*$', re.MULTILINE)

            # Add a refined pattern to catch more variations like "Scalability | 13"
            footer_pattern_3 = re.compile(r'^[A-Za-z\s]+(\s*[\|\-]\s*)\d+\s*$', re.MULTILINE)

            # Additional refined pattern to catch inline footers (e.g., within paragraphs)
            # Match patterns like "Scalability | 13" if followed by a newline or paragraph end
            inline_footer_pattern = re.compile(r'([a-zA-Z\s]+)\s*\|\s*\d+(?=\s*[\n\r])')

            # Remove common footers using all defined patterns
            text = re.sub(footer_pattern_1, '', text)
            text = re.sub(footer_pattern_2, '', text)
            text = re.sub(footer_pattern_3, '', text)

            # Remove inline footers that appear within paragraphs
            text = re.sub(inline_footer_pattern, '', text)

            # Remove page numbers at the beginning or end of lines
            text = re.sub(r'^\s*\d+\s*$', '', text, flags=re.MULTILINE)

            # Remove entire reference sections starting with "References" or "Bibliography"
            reference_section_pattern = re.compile(r'(References|Bibliography)\s*\n.*?(?=\n\n|$)', re.DOTALL)
            text = re.sub(reference_section_pattern, '', text)

            # Remove specific bracketed reference patterns like [1], [ 2 ], [2 ], etc.
            bracketed_reference_pattern = re.compile(r'\[\s*\d+\s*\]')
            text = re.sub(bracketed_reference_pattern, '', text)

            # Handle cases with multiple consecutive references like [1][2][3] or [ 1 ] [ 2 ] [ 3 ]
            multiple_references_pattern = re.compile(r'(\s*\[\s*\d+\s*\]){2,}')
            text = re.sub(multiple_references_pattern, '', text)

            # Normalize multiple consecutive newlines to a single newline
            text = re.sub(r'\n+', '\n', text)

            # Remove leading/trailing whitespace
            return text.strip()

        # Parse the outline into a flat list of chapters with their starting pages
        def parse_outline(outlines, reader):
            chapter_structure = []
            chapter_pattern = re.compile(r'Chapter \d+|^Ch\.\s?\d+', re.IGNORECASE)  # Patterns for typical chapter titles
            for item in outlines:
                if isinstance(item, list):
                    chapter_structure.extend(parse_outline(item, reader))
                else:
                    title = item.title.strip()
                    # Consider only valid chapter entries
                    if chapter_pattern.search(title):
                        chapter_structure.append({
                            "title": title,
                            "start_page": reader.get_destination_page_number(item)
                        })
            return chapter_structure

        # Parse the outline into a flat list of chapters with their starting pages
        chapters = parse_outline(outline, reader)

        if not chapters:
            raise ValueError("No chapters found in the outline. Ensure the PDF has a structured outline.")

        # Loop through chapters to extract content and save to text files
        for i in range(len(chapters)):
            chapter_title = chapters[i]["title"]
            start_page = chapters[i]["start_page"]
            end_page = chapters[i + 1]["start_page"] if i + 1 < len(chapters) else len(reader.pages)

            # Extract chapter text and clean it up
            chapter_text = extract_text(start_page, end_page)
            chapter_text = clean_text(chapter_text)

            # Skip empty chapters
            if not chapter_text:
                continue

            # Define chapter filename and save the content
            safe_title = re.sub(r'[^a-zA-Z0-9 ]', '', chapter_title)  # Remove special characters
            chapter_filename = f"{output_directory}/{safe_title or f'Chapter_{i + 1}'}.txt"

            # Prepend book name at the top of the chapter content
            chapter_header = f"Book name: {book_name}\n\n"
            chapter_content = chapter_header + chapter_text

            # Write to file
            with open(chapter_filename, 'w', encoding='utf-8') as chapter_file:
                chapter_file.write(chapter_content)

            print(f"Chapter '{chapter_title}' extracted to '{chapter_filename}'")

except FileNotFoundError:
    print(f"File '{pdf_name}' not found. Please check the file path and name.")
except ValueError as ve:
    print(ve)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\soric\appdata\local\programs\python\python312\lib\site-packages (3.0.1)
# Chapter 'Chapter 1. Reliable, Scalable, and Maintainable Applications' extracted to 'books/Designing Data Intensive Applications/Chapter 1 Reliable Scalable and Maintainable Applications.txt'
# Chapter 'Chapter 2. Data Models and Query Languages' extracted to 'books/Designing Data Intensive Applications/Chapter 2 Data Models and Query Languages.txt'
# Chapter 'Chapter 3. Storage and Retrieval' extracted to 'books/Designing Data Intensive Applications/Chapter 3 Storage and Retrieval.txt'
# Chapter 'Chapter 4. Encoding and Evolution' extracted to 'books/Designing Data Intensive Applications/Chapter 4 Encoding and Evolution.txt'
# Chapter 'Chapter 5. Replication' extracted to 'books/Designing Data Intensive Applications/Chapter 5 Replication.txt'
# Chapter 'Chapter 6. Partitioning' extracted to 'books/Designing Data Intensive Applications/Chapter 6 Partitioning.txt'
# Chapter 'Chapter 7. Transactions' extracted to 'books/Designing Data Intensive Applications/Chapter 7 Transactions.txt'
# Chapter 'Chapter 8. The Trouble with Distributed Systems' extracted to 'books/Designing Data Intensive Applications/Chapter 8 The Trouble with Distributed Systems.txt'
# Chapter 'Chapter 9. Consistency and Consensus' extracted to 'books/Designing Data Intensive Applications/Chapter 9 Consistency and Consensus.txt'
# Chapter 'Chapter 10. Batch Processing' extracted to 'books/Designing Data Intensive Applications/Chapter 10 Batch Processing.txt'
# Chapter 'Chapter 11. Stream Processing' extracted to 'books/Designing Data Intensive Applications/Chapter 11 Stream Processing.txt'
# Chapter 'Chapter 12. The Future of Data Systems' extracted to 'books/Designing Data Intensive Applications/Chapter 12 The Future of Data Systems.txt'
